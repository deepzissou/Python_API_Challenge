# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from config import wthrapikey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
weather_df = pd.read_csv("C:/Users/DeferentAtom94/OneDrive/Desktop/Resources/Pandas_Challenge/cities1.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Define Url and units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Create query Url
query_url = f"{url}appid={wthrapikey}&units={units}&q="

# %%
#Creating Empty Lists to hold API response information
#===========================================================================
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country_id = []
date = []

# %%
#Create a loop through the list of cites
#===================================================================
#Emulating the example, start with the following statement:

print("Beginning Data Retrieval")
print("================================================")

count = 0
set = 1

#Create For loop while using the enumerate function
#Enumerate() method adds a counter to an iterable and returns it in a form of enumerating object. 
#This enumerated object can then be used directly for loops or converted into a list of tuples using the list() method.

for index, city in enumerate(cities):
    count = count + 1
    #Trying to avoid incurring call rate limits set up a counter to sleep after getting data for the first 50 cities.
    #Using time.sleep() to space out the API calls. Which is why I'm guessing they added "import time" to the starter code
    # dependencies.
    #if statement
    if count == 50:
        count = 1
        set = set + 1
        time.sleep(10)
        
    #Now to print the statement for outcomes using the example that was given in the starter code.
    print(f"Processing Record {count} of Set {set} | {city}")
    
    #Present the try statement requesting data from the url + city variable and append to the empty lists
    try:
        response = requests.get(url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main'][temp_max])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country_id.append(response['sys']['country'])
        date.append(response['dt'])
        
    #Create a except error statement so that the code continues to run even if an error occurs.
    #Print error statement emulating the example from the starter code
    except KeyError:
        print("City not found. Skipping...")
    #In Python, NumPy NAN stands for not a number
    # and is defined as a substitute for declaring value which are numerical values
    # that are missing values in an array as NumPy is used to deal with arrays in Python
    # and this can be initialized using numpy.  
    
        lat.append(np.nan)
        lng.append(np.nan)
        max_temp.append(np.nan)
        humidity.append(np.nan)
        cloudiness.append(np.nan)
        wind_speed.append(np.nan)
        country_id.append(np.nan)
        date.append(np.nan)
        
#Print ending statement and spacers emulating the example from the starter code  
print("===========================================================") 
print("Data Retrieval Complete")
print("===========================================================")
# Out:
# Beginning Data Retrieval
# ================================================
# Processing Record 1 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 2 of Set 1 | mitsamiouli
# City not found. Skipping...
# Processing Record 3 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 4 of Set 1 | george
# City not found. Skipping...
# Processing Record 5 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 6 of Set 1 | samarai
# City not found. Skipping...
# Processing Record 7 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 8 of Set 1 | north platte
# City not found. Skipping...
# Processing Record 9 of Set 1 | chuy
# City not found. Skipping...
# Processing Record 10 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 1 | khatanga
# City not found. Skipping...
# Processing Record 12 of Set 1 | juifang
# City not found. Skipping...
# Processing Record 13 of Set 1 | kargasok
# City not found. Skipping...
# Processing Record 14 of Set 1 | half moon bay
# City not found. Skipping...
# Processing Record 15 of Set 1 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 16 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 17 of Set 1 | tolu
# City not found. Skipping...
# Processing Record 18 of Set 1 | east london
# City not found. Skipping...
# Processing Record 19 of Set 1 | dikson
# City not found. Skipping...
# Processing Record 20 of Set 1 | longyearbyen
# City not found. Skipping...
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | victoria point
# City not found. Skipping...
# Processing Record 23 of Set 1 | tarko-sale
# City not found. Skipping...
# Processing Record 24 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 25 of Set 1 | saldanha
# City not found. Skipping...
# Processing Record 26 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 27 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 28 of Set 1 | zarate
# City not found. Skipping...
# Processing Record 29 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 1 | lorengau
# City not found. Skipping...
# Processing Record 31 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 32 of Set 1 | novoorsk
# City not found. Skipping...
# Processing Record 33 of Set 1 | kosa
# City not found. Skipping...
# Processing Record 34 of Set 1 | merauke
# City not found. Skipping...
# Processing Record 35 of Set 1 | lasa
# City not found. Skipping...
# Processing Record 36 of Set 1 | inongo
# City not found. Skipping...
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | azul
# City not found. Skipping...
# Processing Record 39 of Set 1 | sindand
# City not found. Skipping...
# Processing Record 40 of Set 1 | hilo
# City not found. Skipping...
# Processing Record 41 of Set 1 | broome
# City not found. Skipping...
# Processing Record 42 of Set 1 | evensk
# City not found. Skipping...
# Processing Record 43 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 44 of Set 1 | upernavik
# City not found. Skipping...
# Processing Record 45 of Set 1 | victoria
# City not found. Skipping...
# Processing Record 46 of Set 1 | le vauclin
# City not found. Skipping...
# Processing Record 47 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 1 | sambava
# City not found. Skipping...
# Processing Record 49 of Set 1 | hamilton
# City not found. Skipping...
# Processing Record 1 of Set 2 | kapaa
# City not found. Skipping...
# Processing Record 2 of Set 2 | kavieng
# City not found. Skipping...
# Processing Record 3 of Set 2 | albany
# City not found. Skipping...
# Processing Record 4 of Set 2 | sao filipe
# City not found. Skipping...
# Processing Record 5 of Set 2 | chokurdakh
# City not found. Skipping...
# Processing Record 6 of Set 2 | abha
# City not found. Skipping...
# Processing Record 7 of Set 2 | haines junction
# City not found. Skipping...
# Processing Record 8 of Set 2 | mar del plata
# City not found. Skipping...
# Processing Record 9 of Set 2 | cabedelo
# City not found. Skipping...
# Processing Record 10 of Set 2 | bluff
# City not found. Skipping...
# Processing Record 11 of Set 2 | sitka
# City not found. Skipping...
# Processing Record 12 of Set 2 | jamestown
# City not found. Skipping...
# Processing Record 13 of Set 2 | castro
# City not found. Skipping...
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | bubaque
# City not found. Skipping...
# Processing Record 16 of Set 2 | hithadhoo
# City not found. Skipping...
# Processing Record 17 of Set 2 | neiafu
# City not found. Skipping...
# Processing Record 18 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record 19 of Set 2 | nanortalik
# City not found. Skipping...
# Processing Record 20 of Set 2 | namatanai
# City not found. Skipping...
# Processing Record 21 of Set 2 | butaritari
# City not found. Skipping...
# Processing Record 22 of Set 2 | busselton
# City not found. Skipping...
# Processing Record 23 of Set 2 | severo-kurilsk
# City not found. Skipping...
# Processing Record 24 of Set 2 | fortuna
# City not found. Skipping...
# Processing Record 25 of Set 2 | ahuimanu
# City not found. Skipping...
# Processing Record 26 of Set 2 | tasiilaq
# City not found. Skipping...
# Processing Record 27 of Set 2 | sao gabriel da cachoeira
# City not found. Skipping...
# Processing Record 28 of Set 2 | cape town
# City not found. Skipping...
# Processing Record 29 of Set 2 | ponta do sol
# City not found. Skipping...
# Processing Record 30 of Set 2 | ahipara
# City not found. Skipping...
# Processing Record 31 of Set 2 | hobart
# City not found. Skipping...
# Processing Record 32 of Set 2 | kruisfontein
# City not found. Skipping...
# Processing Record 33 of Set 2 | barrow
# City not found. Skipping...
# Processing Record 34 of Set 2 | kavaratti
# City not found. Skipping...
# Processing Record 35 of Set 2 | lazurne
# City not found. Skipping...
# Processing Record 36 of Set 2 | boden
# City not found. Skipping...
# Processing Record 37 of Set 2 | avarua
# City not found. Skipping...
# Processing Record 38 of Set 2 | moshny
# City not found. Skipping...
# Processing Record 39 of Set 2 | auki
# City not found. Skipping...
# Processing Record 40 of Set 2 | pimentel
# City not found. Skipping...
# Processing Record 41 of Set 2 | cannington
# City not found. Skipping...
# Processing Record 42 of Set 2 | kurilsk
# City not found. Skipping...
# Processing Record 43 of Set 2 | teluk nibung
# City not found. Skipping...
# Processing Record 44 of Set 2 | tabou
# City not found. Skipping...
# Processing Record 45 of Set 2 | olafsvik
# City not found. Skipping...
# Processing Record 46 of Set 2 | jomalig
# City not found. Skipping...
# Processing Record 47 of Set 2 | ati
# City not found. Skipping...
# Processing Record 48 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 2 | carnarvon
# City not found. Skipping...
# Processing Record 1 of Set 3 | margate
# City not found. Skipping...
# Processing Record 2 of Set 3 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 3 of Set 3 | atuona
# City not found. Skipping...
# Processing Record 4 of Set 3 | los llanos de aridane
# City not found. Skipping...
# Processing Record 5 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 6 of Set 3 | kisangani
# City not found. Skipping...
# Processing Record 7 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 8 of Set 3 | korla
# City not found. Skipping...
# Processing Record 9 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 3 | itupiranga
# City not found. Skipping...
# Processing Record 11 of Set 3 | alofi
# City not found. Skipping...
# Processing Record 12 of Set 3 | bay roberts
# City not found. Skipping...
# Processing Record 13 of Set 3 | formosa
# City not found. Skipping...
# Processing Record 14 of Set 3 | kodiak
# City not found. Skipping...
# Processing Record 15 of Set 3 | ranong
# City not found. Skipping...
# Processing Record 16 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 3 | saint-philippe
# City not found. Skipping...
# Processing Record 18 of Set 3 | kavant
# City not found. Skipping...
# Processing Record 19 of Set 3 | miranda
# City not found. Skipping...
# Processing Record 20 of Set 3 | townsville
# City not found. Skipping...
# Processing Record 21 of Set 3 | tiksi
# City not found. Skipping...
# Processing Record 22 of Set 3 | saint-leu
# City not found. Skipping...
# Processing Record 23 of Set 3 | orumiyeh
# City not found. Skipping...
# Processing Record 24 of Set 3 | ketchikan
# City not found. Skipping...
# Processing Record 25 of Set 3 | carikar
# City not found. Skipping...
# Processing Record 26 of Set 3 | mahebourg
# City not found. Skipping...
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 3 | laguna
# City not found. Skipping...
# Processing Record 30 of Set 3 | cabinda
# City not found. Skipping...
# Processing Record 31 of Set 3 | isangel
# City not found. Skipping...
# Processing Record 32 of Set 3 | kaitangata
# City not found. Skipping...
# Processing Record 33 of Set 3 | kantilo
# City not found. Skipping...
# Processing Record 34 of Set 3 | cedar mill
# City not found. Skipping...
# Processing Record 35 of Set 3 | atar
# City not found. Skipping...
# Processing Record 36 of Set 3 | cabo san lucas
# City not found. Skipping...
# Processing Record 37 of Set 3 | salalah
# City not found. Skipping...
# Processing Record 38 of Set 3 | saint anthony
# City not found. Skipping...
# Processing Record 39 of Set 3 | gokak
# City not found. Skipping...
# Processing Record 40 of Set 3 | flinders
# City not found. Skipping...
# Processing Record 41 of Set 3 | riachao das neves
# City not found. Skipping...
# Processing Record 42 of Set 3 | lagoa
# City not found. Skipping...
# Processing Record 43 of Set 3 | turukhansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | pacific grove
# City not found. Skipping...
# Processing Record 45 of Set 3 | kang
# City not found. Skipping...
# Processing Record 46 of Set 3 | balimo
# City not found. Skipping...
# Processing Record 47 of Set 3 | college
# City not found. Skipping...
# Processing Record 48 of Set 3 | yeppoon
# City not found. Skipping...
# Processing Record 49 of Set 3 | la ronge
# City not found. Skipping...
# Processing Record 1 of Set 4 | cidreira
# City not found. Skipping...
# Processing Record 2 of Set 4 | price
# City not found. Skipping...
# Processing Record 3 of Set 4 | kirakira
# City not found. Skipping...
# Processing Record 4 of Set 4 | luanda
# City not found. Skipping...
# Processing Record 5 of Set 4 | mackay
# City not found. Skipping...
# Processing Record 6 of Set 4 | beruwala
# City not found. Skipping...
# Processing Record 7 of Set 4 | gari
# City not found. Skipping...
# Processing Record 8 of Set 4 | jieshi
# City not found. Skipping...
# Processing Record 9 of Set 4 | praya
# City not found. Skipping...
# Processing Record 10 of Set 4 | beringovskiy
# City not found. Skipping...
# Processing Record 11 of Set 4 | naryan-mar
# City not found. Skipping...
# Processing Record 12 of Set 4 | plettenberg bay
# City not found. Skipping...
# Processing Record 13 of Set 4 | kobojango
# City not found. Skipping...
# Processing Record 14 of Set 4 | ferrol
# City not found. Skipping...
# Processing Record 15 of Set 4 | campo maior
# City not found. Skipping...
# Processing Record 16 of Set 4 | gunjur
# City not found. Skipping...
# Processing Record 17 of Set 4 | nsukka
# City not found. Skipping...
# Processing Record 18 of Set 4 | hameenlinna
# City not found. Skipping...
# Processing Record 19 of Set 4 | thompson
# City not found. Skipping...
# Processing Record 20 of Set 4 | pontianak
# City not found. Skipping...
# Processing Record 21 of Set 4 | bestobe
# City not found. Skipping...
# Processing Record 22 of Set 4 | mabaruma
# City not found. Skipping...
# Processing Record 23 of Set 4 | puerto ayora
# City not found. Skipping...
# Processing Record 24 of Set 4 | tshikapa
# City not found. Skipping...
# Processing Record 25 of Set 4 | fairbanks
# City not found. Skipping...
# Processing Record 26 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 4 | hofn
# City not found. Skipping...
# Processing Record 28 of Set 4 | esperance
# City not found. Skipping...
# Processing Record 29 of Set 4 | la baule-escoublac
# City not found. Skipping...
# Processing Record 30 of Set 4 | hambantota
# City not found. Skipping...
# Processing Record 31 of Set 4 | cockburn town
# City not found. Skipping...
# Processing Record 32 of Set 4 | ekhabi
# City not found. Skipping...
# Processing Record 33 of Set 4 | pangnirtung
# City not found. Skipping...
# Processing Record 34 of Set 4 | qaanaaq
# City not found. Skipping...
# Processing Record 35 of Set 4 | novyy urgal
# City not found. Skipping...
# Processing Record 36 of Set 4 | ribeira grande
# City not found. Skipping...
# Processing Record 37 of Set 4 | taoudenni
# City not found. Skipping...
# Processing Record 38 of Set 4 | la rioja
# City not found. Skipping...
# Processing Record 39 of Set 4 | san isidro
# City not found. Skipping...
# Processing Record 40 of Set 4 | vreed en hoop
# City not found. Skipping...
# Processing Record 41 of Set 4 | vila franca do campo
# City not found. Skipping...
# Processing Record 42 of Set 4 | lompoc
# City not found. Skipping...
# Processing Record 43 of Set 4 | zaysan
# City not found. Skipping...
# Processing Record 44 of Set 4 | hasaki
# City not found. Skipping...
# Processing Record 45 of Set 4 | port lincoln
# City not found. Skipping...
# Processing Record 46 of Set 4 | provideniya
# City not found. Skipping...
# Processing Record 47 of Set 4 | brinkovskaya
# City not found. Skipping...
# Processing Record 48 of Set 4 | lahij
# City not found. Skipping...
# Processing Record 49 of Set 4 | yellowknife
# City not found. Skipping...
# Processing Record 1 of Set 5 | broken hill
# City not found. Skipping...
# Processing Record 2 of Set 5 | xiongshi
# City not found. Skipping...
# Processing Record 3 of Set 5 | mwense
# City not found. Skipping...
# Processing Record 4 of Set 5 | novikovo
# City not found. Skipping...
# Processing Record 5 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 5 | port hardy
# City not found. Skipping...
# Processing Record 7 of Set 5 | vilyuysk
# City not found. Skipping...
# Processing Record 8 of Set 5 | zarumilla
# City not found. Skipping...
# Processing Record 9 of Set 5 | preobrazheniye
# City not found. Skipping...
# Processing Record 10 of Set 5 | hermanus
# City not found. Skipping...
# Processing Record 11 of Set 5 | ternate
# City not found. Skipping...
# Processing Record 12 of Set 5 | verkhozim
# City not found. Skipping...
# Processing Record 13 of Set 5 | te anau
# City not found. Skipping...
# Processing Record 14 of Set 5 | honningsvag
# City not found. Skipping...
# Processing Record 15 of Set 5 | tual
# City not found. Skipping...
# Processing Record 16 of Set 5 | san patricio
# City not found. Skipping...
# Processing Record 17 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 5 | torbay
# City not found. Skipping...
# Processing Record 19 of Set 5 | amapa
# City not found. Skipping...
# Processing Record 20 of Set 5 | zhanaozen
# City not found. Skipping...
# Processing Record 21 of Set 5 | portaria
# City not found. Skipping...
# Processing Record 22 of Set 5 | leningradskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 5 | arraial do cabo
# City not found. Skipping...
# Processing Record 25 of Set 5 | klaksvik
# City not found. Skipping...
# Processing Record 26 of Set 5 | pevek
# City not found. Skipping...
# Processing Record 27 of Set 5 | saint-pierre
# City not found. Skipping...
# Processing Record 28 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 5 | naugachhia
# City not found. Skipping...
# Processing Record 30 of Set 5 | guaratinga
# City not found. Skipping...
# Processing Record 31 of Set 5 | ormara
# City not found. Skipping...
# Processing Record 32 of Set 5 | salamiyah
# City not found. Skipping...
# Processing Record 33 of Set 5 | krasnovishersk
# City not found. Skipping...
# Processing Record 34 of Set 5 | nishihara
# City not found. Skipping...
# Processing Record 35 of Set 5 | krivopolyanye
# City not found. Skipping...
# Processing Record 36 of Set 5 | sarai alamgir
# City not found. Skipping...
# Processing Record 37 of Set 5 | pouebo
# City not found. Skipping...
# Processing Record 38 of Set 5 | lima
# City not found. Skipping...
# Processing Record 39 of Set 5 | vardo
# City not found. Skipping...
# Processing Record 40 of Set 5 | guerrero negro
# City not found. Skipping...
# Processing Record 41 of Set 5 | faya
# City not found. Skipping...
# Processing Record 42 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 43 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 5 | padang
# City not found. Skipping...
# Processing Record 45 of Set 5 | ambilobe
# City not found. Skipping...
# Processing Record 46 of Set 5 | buchmany
# City not found. Skipping...
# Processing Record 47 of Set 5 | berlevag
# City not found. Skipping...
# Processing Record 48 of Set 5 | itagiba
# City not found. Skipping...
# Processing Record 49 of Set 5 | saskylakh
# City not found. Skipping...
# Processing Record 1 of Set 6 | tezu
# City not found. Skipping...
# Processing Record 2 of Set 6 | arlit
# City not found. Skipping...
# Processing Record 3 of Set 6 | xining
# City not found. Skipping...
# Processing Record 4 of Set 6 | bandarbeyla
# City not found. Skipping...
# Processing Record 5 of Set 6 | port elizabeth
# City not found. Skipping...
# Processing Record 6 of Set 6 | ouanaminthe
# City not found. Skipping...
# Processing Record 7 of Set 6 | nikolskoye
# City not found. Skipping...
# Processing Record 8 of Set 6 | grand gaube
# City not found. Skipping...
# Processing Record 9 of Set 6 | deputatskiy
# City not found. Skipping...
# Processing Record 10 of Set 6 | svetlopolyansk
# City not found. Skipping...
# Processing Record 11 of Set 6 | sehithwa
# City not found. Skipping...
# Processing Record 12 of Set 6 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 13 of Set 6 | nizhniy ingash
# City not found. Skipping...
# Processing Record 14 of Set 6 | guhagar
# City not found. Skipping...
# Processing Record 15 of Set 6 | asau
# City not found. Skipping...
# Processing Record 16 of Set 6 | faanui
# City not found. Skipping...
# Processing Record 17 of Set 6 | mildura
# City not found. Skipping...
# Processing Record 18 of Set 6 | paso de carrasco
# City not found. Skipping...
# Processing Record 19 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 6 | norrkoping
# City not found. Skipping...
# Processing Record 21 of Set 6 | beyneu
# City not found. Skipping...
# Processing Record 22 of Set 6 | zhireken
# City not found. Skipping...
# Processing Record 23 of Set 6 | qui nhon
# City not found. Skipping...
# Processing Record 24 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 26 of Set 6 | yefremov
# City not found. Skipping...
# Processing Record 27 of Set 6 | nome
# City not found. Skipping...
# Processing Record 28 of Set 6 | novyy urengoy
# City not found. Skipping...
# Processing Record 29 of Set 6 | cherskiy
# City not found. Skipping...
# Processing Record 30 of Set 6 | saint-augustin
# City not found. Skipping...
# Processing Record 31 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 6 | shimoda
# City not found. Skipping...
# Processing Record 33 of Set 6 | honjo
# City not found. Skipping...
# Processing Record 34 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 6 | rocha
# City not found. Skipping...
# Processing Record 36 of Set 6 | norman wells
# City not found. Skipping...
# Processing Record 37 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 38 of Set 6 | tucuman
# City not found. Skipping...
# Processing Record 39 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 40 of Set 6 | san cristobal
# City not found. Skipping...
# Processing Record 41 of Set 6 | kashi
# City not found. Skipping...
# Processing Record 42 of Set 6 | poum
# City not found. Skipping...
# Processing Record 43 of Set 6 | sabang
# City not found. Skipping...
# Processing Record 44 of Set 6 | kiama
# City not found. Skipping...
# Processing Record 45 of Set 6 | maldonado
# City not found. Skipping...
# Processing Record 46 of Set 6 | awjilah
# City not found. Skipping...
# Processing Record 47 of Set 6 | puerto ayacucho
# City not found. Skipping...
# Processing Record 48 of Set 6 | bethel
# City not found. Skipping...
# Processing Record 49 of Set 6 | yar-sale
# City not found. Skipping...
# Processing Record 1 of Set 7 | rundu
# City not found. Skipping...
# Processing Record 2 of Set 7 | bambous virieux
# City not found. Skipping...
# Processing Record 3 of Set 7 | buenos aires
# City not found. Skipping...
# Processing Record 4 of Set 7 | mount gambier
# City not found. Skipping...
# Processing Record 5 of Set 7 | lucea
# City not found. Skipping...
# Processing Record 6 of Set 7 | porto santo
# City not found. Skipping...
# Processing Record 7 of Set 7 | cayenne
# City not found. Skipping...
# Processing Record 8 of Set 7 | nuuk
# City not found. Skipping...
# Processing Record 9 of Set 7 | kichera
# City not found. Skipping...
# Processing Record 10 of Set 7 | tautira
# City not found. Skipping...
# Processing Record 11 of Set 7 | solnechnyy
# City not found. Skipping...
# Processing Record 12 of Set 7 | okhotsk
# City not found. Skipping...
# Processing Record 13 of Set 7 | adrar
# City not found. Skipping...
# Processing Record 14 of Set 7 | huaihua
# City not found. Skipping...
# Processing Record 15 of Set 7 | kobryn
# City not found. Skipping...
# Processing Record 16 of Set 7 | bilma
# City not found. Skipping...
# Processing Record 17 of Set 7 | albanel
# City not found. Skipping...
# Processing Record 18 of Set 7 | riyadh
# City not found. Skipping...
# Processing Record 19 of Set 7 | ogaminana
# City not found. Skipping...
# Processing Record 20 of Set 7 | victor harbor
# City not found. Skipping...
# Processing Record 21 of Set 7 | sanmenxia
# City not found. Skipping...
# Processing Record 22 of Set 7 | buta
# City not found. Skipping...
# Processing Record 23 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 7 | saint george
# City not found. Skipping...
# Processing Record 25 of Set 7 | tiradentes
# City not found. Skipping...
# Processing Record 26 of Set 7 | vila velha
# City not found. Skipping...
# Processing Record 27 of Set 7 | tomatlan
# City not found. Skipping...
# Processing Record 28 of Set 7 | boa vista
# City not found. Skipping...
# Processing Record 29 of Set 7 | spremberg
# City not found. Skipping...
# Processing Record 30 of Set 7 | caravelas
# City not found. Skipping...
# Processing Record 31 of Set 7 | mata
# City not found. Skipping...
# Processing Record 32 of Set 7 | pisco
# City not found. Skipping...
# Processing Record 33 of Set 7 | paraiso
# City not found. Skipping...
# Processing Record 34 of Set 7 | dicabisagan
# City not found. Skipping...
# Processing Record 35 of Set 7 | los lunas
# City not found. Skipping...
# Processing Record 36 of Set 7 | baracoa
# City not found. Skipping...
# Processing Record 37 of Set 7 | berdigestyakh
# City not found. Skipping...
# Processing Record 38 of Set 7 | georgetown
# City not found. Skipping...
# Processing Record 39 of Set 7 | sokolo
# City not found. Skipping...
# Processing Record 40 of Set 7 | marsh harbour
# City not found. Skipping...
# Processing Record 41 of Set 7 | kushiro
# City not found. Skipping...
# Processing Record 42 of Set 7 | aykhal
# City not found. Skipping...
# Processing Record 43 of Set 7 | menongue
# City not found. Skipping...
# Processing Record 44 of Set 7 | robertsport
# City not found. Skipping...
# Processing Record 45 of Set 7 | zhezkazgan
# City not found. Skipping...
# Processing Record 46 of Set 7 | piacabucu
# City not found. Skipping...
# Processing Record 47 of Set 7 | liyang
# City not found. Skipping...
# Processing Record 48 of Set 7 | heyang
# City not found. Skipping...
# Processing Record 49 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 8 | iskateley
# City not found. Skipping...
# Processing Record 2 of Set 8 | souillac
# City not found. Skipping...
# Processing Record 3 of Set 8 | itarantim
# City not found. Skipping...
# Processing Record 4 of Set 8 | kununurra
# City not found. Skipping...
# Processing Record 5 of Set 8 | lake cowichan
# City not found. Skipping...
# Processing Record 6 of Set 8 | chabahar
# City not found. Skipping...
# Processing Record 7 of Set 8 | pombia
# City not found. Skipping...
# Processing Record 8 of Set 8 | kloulklubed
# City not found. Skipping...
# Processing Record 9 of Set 8 | ostrovnoy
# City not found. Skipping...
# Processing Record 10 of Set 8 | ubauro
# City not found. Skipping...
# Processing Record 11 of Set 8 | hualmay
# City not found. Skipping...
# Processing Record 12 of Set 8 | port-cartier
# City not found. Skipping...
# Processing Record 13 of Set 8 | coquimbo
# City not found. Skipping...
# Processing Record 14 of Set 8 | srednekolymsk
# City not found. Skipping...
# Processing Record 15 of Set 8 | sur
# City not found. Skipping...
# Processing Record 16 of Set 8 | meulaboh
# City not found. Skipping...
# Processing Record 17 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 18 of Set 8 | sawakin
# City not found. Skipping...
# Processing Record 19 of Set 8 | christchurch
# City not found. Skipping...
# Processing Record 20 of Set 8 | zimovniki
# City not found. Skipping...
# Processing Record 21 of Set 8 | pacifica
# City not found. Skipping...
# Processing Record 22 of Set 8 | hearst
# City not found. Skipping...
# Processing Record 23 of Set 8 | fianga
# City not found. Skipping...
# Processing Record 24 of Set 8 | sorong
# City not found. Skipping...
# Processing Record 25 of Set 8 | grand forks
# City not found. Skipping...
# Processing Record 26 of Set 8 | sao felix do xingu
# City not found. Skipping...
# Processing Record 27 of Set 8 | lavras
# City not found. Skipping...
# Processing Record 28 of Set 8 | tommot
# City not found. Skipping...
# Processing Record 29 of Set 8 | rockland
# City not found. Skipping...
# Processing Record 30 of Set 8 | ilovlya
# City not found. Skipping...
# Processing Record 31 of Set 8 | brae
# City not found. Skipping...
# Processing Record 32 of Set 8 | nantucket
# City not found. Skipping...
# Processing Record 33 of Set 8 | waipawa
# City not found. Skipping...
# Processing Record 34 of Set 8 | itoman
# City not found. Skipping...
# Processing Record 35 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 8 | aklavik
# City not found. Skipping...
# Processing Record 37 of Set 8 | koumac
# City not found. Skipping...
# Processing Record 38 of Set 8 | tarbert
# City not found. Skipping...
# Processing Record 39 of Set 8 | oistins
# City not found. Skipping...
# Processing Record 40 of Set 8 | santa cruz
# City not found. Skipping...
# Processing Record 41 of Set 8 | matara
# City not found. Skipping...
# Processing Record 42 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 8 | scarborough
# City not found. Skipping...
# Processing Record 44 of Set 8 | port pirie
# City not found. Skipping...
# Processing Record 45 of Set 8 | port blair
# City not found. Skipping...
# Processing Record 46 of Set 8 | mumford
# City not found. Skipping...
# Processing Record 47 of Set 8 | san rafael
# City not found. Skipping...
# Processing Record 48 of Set 8 | aqtobe
# City not found. Skipping...
# Processing Record 49 of Set 8 | severnoye
# City not found. Skipping...
# Processing Record 1 of Set 9 | ulladulla
# City not found. Skipping...
# Processing Record 2 of Set 9 | mehamn
# City not found. Skipping...
# Processing Record 3 of Set 9 | henties bay
# City not found. Skipping...
# Processing Record 4 of Set 9 | khvoynaya
# City not found. Skipping...
# Processing Record 5 of Set 9 | chimay
# City not found. Skipping...
# Processing Record 6 of Set 9 | mayo
# City not found. Skipping...
# Processing Record 7 of Set 9 | okato
# City not found. Skipping...
# Processing Record 8 of Set 9 | najran
# City not found. Skipping...
# Processing Record 9 of Set 9 | chapais
# City not found. Skipping...
# Processing Record 10 of Set 9 | biak
# City not found. Skipping...
# Processing Record 11 of Set 9 | codrington
# City not found. Skipping...
# Processing Record 12 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 9 | staronizhestebliyevskaya
# City not found. Skipping...
# Processing Record 14 of Set 9 | rio grande
# City not found. Skipping...
# Processing Record 15 of Set 9 | lixourion
# City not found. Skipping...
# Processing Record 16 of Set 9 | taos
# City not found. Skipping...
# Processing Record 17 of Set 9 | sistranda
# City not found. Skipping...
# Processing Record 18 of Set 9 | prata
# City not found. Skipping...
# Processing Record 19 of Set 9 | havoysund
# City not found. Skipping...
# Processing Record 20 of Set 9 | sarangani
# City not found. Skipping...
# Processing Record 21 of Set 9 | miracema do tocantins
# City not found. Skipping...
# Processing Record 22 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 9 | talnakh
# City not found. Skipping...
# Processing Record 24 of Set 9 | seymchan
# City not found. Skipping...
# Processing Record 25 of Set 9 | maryborough
# City not found. Skipping...
# Processing Record 26 of Set 9 | mariel
# City not found. Skipping...
# Processing Record 27 of Set 9 | gobabis
# City not found. Skipping...
# Processing Record 28 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 9 | lavrentiya
# City not found. Skipping...
# Processing Record 30 of Set 9 | jerome
# City not found. Skipping...
# Processing Record 31 of Set 9 | sao joao da barra
# City not found. Skipping...
# Processing Record 32 of Set 9 | ust-tsilma
# City not found. Skipping...
# Processing Record 33 of Set 9 | keti bandar
# City not found. Skipping...
# Processing Record 34 of Set 9 | makubetsu
# City not found. Skipping...
# Processing Record 35 of Set 9 | cuamba
# City not found. Skipping...
# Processing Record 36 of Set 9 | lewistown
# City not found. Skipping...
# Processing Record 37 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 38 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 9 | sabha
# City not found. Skipping...
# Processing Record 40 of Set 9 | quatre cocos
# City not found. Skipping...
# Processing Record 41 of Set 9 | husavik
# City not found. Skipping...
# Processing Record 42 of Set 9 | kastamonu
# City not found. Skipping...
# Processing Record 43 of Set 9 | geraldton
# City not found. Skipping...
# Processing Record 44 of Set 9 | andenes
# City not found. Skipping...
# Processing Record 45 of Set 9 | conde
# City not found. Skipping...
# Processing Record 46 of Set 9 | pavilosta
# City not found. Skipping...
# Processing Record 47 of Set 9 | naze
# City not found. Skipping...
# Processing Record 48 of Set 9 | bardiyah
# City not found. Skipping...
# Processing Record 49 of Set 9 | jajce
# City not found. Skipping...
# Processing Record 1 of Set 10 | esso
# City not found. Skipping...
# Processing Record 2 of Set 10 | airai
# City not found. Skipping...
# Processing Record 3 of Set 10 | yamada
# City not found. Skipping...
# Processing Record 4 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 10 | bogorodskoye
# City not found. Skipping...
# Processing Record 6 of Set 10 | duobao
# City not found. Skipping...
# Processing Record 7 of Set 10 | carutapera
# City not found. Skipping...
# Processing Record 8 of Set 10 | mugur-aksy
# City not found. Skipping...
# Processing Record 9 of Set 10 | wanning
# City not found. Skipping...
# Processing Record 10 of Set 10 | lakhdenpokhya
# City not found. Skipping...
# Processing Record 11 of Set 10 | laurel
# City not found. Skipping...
# Processing Record 12 of Set 10 | wanderlandia
# City not found. Skipping...
# Processing Record 13 of Set 10 | kifri
# City not found. Skipping...
# Processing Record 14 of Set 10 | kiunga
# City not found. Skipping...
# Processing Record 15 of Set 10 | chiang rai
# City not found. Skipping...
# Processing Record 16 of Set 10 | carauari
# City not found. Skipping...
# Processing Record 17 of Set 10 | kasongo-lunda
# City not found. Skipping...
# Processing Record 18 of Set 10 | hobyo
# City not found. Skipping...
# Processing Record 19 of Set 10 | greenville
# City not found. Skipping...
# Processing Record 20 of Set 10 | roma
# City not found. Skipping...
# Processing Record 21 of Set 10 | fort nelson
# City not found. Skipping...
# Processing Record 22 of Set 10 | champua
# City not found. Skipping...
# Processing Record 23 of Set 10 | masallatah
# City not found. Skipping...
# Processing Record 24 of Set 10 | aksu
# City not found. Skipping...
# Processing Record 25 of Set 10 | ballina
# City not found. Skipping...
# Processing Record 26 of Set 10 | asyut
# City not found. Skipping...
# Processing Record 27 of Set 10 | lugovskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | rawson
# City not found. Skipping...
# Processing Record 29 of Set 10 | kartaly
# City not found. Skipping...
# Processing Record 30 of Set 10 | pedro carbo
# City not found. Skipping...
# Processing Record 31 of Set 10 | garden city
# City not found. Skipping...
# Processing Record 32 of Set 10 | podgorica
# City not found. Skipping...
# Processing Record 33 of Set 10 | puerto el triunfo
# City not found. Skipping...
# Processing Record 34 of Set 10 | sampit
# City not found. Skipping...
# Processing Record 35 of Set 10 | kurchum
# City not found. Skipping...
# Processing Record 36 of Set 10 | bridlington
# City not found. Skipping...
# Processing Record 37 of Set 10 | poplar bluff
# City not found. Skipping...
# Processing Record 38 of Set 10 | buchanan
# City not found. Skipping...
# Processing Record 39 of Set 10 | narsaq
# City not found. Skipping...
# Processing Record 40 of Set 10 | ferrenafe
# City not found. Skipping...
# Processing Record 41 of Set 10 | caucaia
# City not found. Skipping...
# Processing Record 42 of Set 10 | hanyang
# City not found. Skipping...
# Processing Record 43 of Set 10 | karratha
# City not found. Skipping...
# Processing Record 44 of Set 10 | suzhou
# City not found. Skipping...
# Processing Record 45 of Set 10 | lukovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 10 | port macquarie
# City not found. Skipping...
# Processing Record 47 of Set 10 | vestmanna
# City not found. Skipping...
# Processing Record 48 of Set 10 | dingle
# City not found. Skipping...
# Processing Record 49 of Set 10 | itarema
# City not found. Skipping...
# Processing Record 1 of Set 11 | bermeo
# City not found. Skipping...
# Processing Record 2 of Set 11 | praia da vitoria
# City not found. Skipping...
# Processing Record 3 of Set 11 | saint-ambroise
# City not found. Skipping...
# Processing Record 4 of Set 11 | druzhba
# City not found. Skipping...
# Processing Record 5 of Set 11 | novobirilyussy
# City not found. Skipping...
# Processing Record 6 of Set 11 | badiraguato
# City not found. Skipping...
# Processing Record 7 of Set 11 | kahului
# City not found. Skipping...
# Processing Record 8 of Set 11 | kampot
# City not found. Skipping...
# Processing Record 9 of Set 11 | presidencia roque saenz pena
# City not found. Skipping...
# Processing Record 10 of Set 11 | iqaluit
# City not found. Skipping...
# Processing Record 11 of Set 11 | khani
# City not found. Skipping...
# Processing Record 12 of Set 11 | ilulissat
# City not found. Skipping...
# Processing Record 13 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 14 of Set 11 | alta floresta
# City not found. Skipping...
# Processing Record 15 of Set 11 | vanavara
# City not found. Skipping...
# Processing Record 16 of Set 11 | clyde river
# City not found. Skipping...
# Processing Record 17 of Set 11 | kharan
# City not found. Skipping...
# Processing Record 18 of Set 11 | karpogory
# City not found. Skipping...
# Processing Record 19 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 11 | changde
# City not found. Skipping...
# Processing Record 22 of Set 11 | pangody
# City not found. Skipping...
# Processing Record 23 of Set 11 | usila
# City not found. Skipping...
# Processing Record 24 of Set 11 | black river
# City not found. Skipping...
# Processing Record 25 of Set 11 | pindobacu
# City not found. Skipping...
# Processing Record 26 of Set 11 | pandan
# City not found. Skipping...
# Processing Record 27 of Set 11 | talakan
# City not found. Skipping...
# Processing Record 28 of Set 11 | grootfontein
# City not found. Skipping...
# Processing Record 29 of Set 11 | zanjan
# City not found. Skipping...
# Processing Record 30 of Set 11 | abu dhabi
# City not found. Skipping...
# Processing Record 31 of Set 11 | coihaique
# City not found. Skipping...
# Processing Record 32 of Set 11 | ryotsu
# City not found. Skipping...
# Processing Record 33 of Set 11 | baykit
# City not found. Skipping...
# Processing Record 34 of Set 11 | mocuba
# City not found. Skipping...
# Processing Record 35 of Set 11 | san quintin
# City not found. Skipping...
# Processing Record 36 of Set 11 | shizunai
# City not found. Skipping...
# Processing Record 37 of Set 11 | kaeo
# City not found. Skipping...
# Processing Record 38 of Set 11 | kelvington
# City not found. Skipping...
# Processing Record 39 of Set 11 | sesheke
# City not found. Skipping...
# Processing Record 40 of Set 11 | capreol
# City not found. Skipping...
# Processing Record 41 of Set 11 | siuri
# City not found. Skipping...
# Processing Record 42 of Set 11 | sveio
# City not found. Skipping...
# Processing Record 43 of Set 11 | hami
# City not found. Skipping...
# Processing Record 44 of Set 11 | twin falls
# City not found. Skipping...
# Processing Record 45 of Set 11 | yarim
# City not found. Skipping...
# Processing Record 46 of Set 11 | vao
# City not found. Skipping...
# Processing Record 47 of Set 11 | bainbridge
# City not found. Skipping...
# Processing Record 48 of Set 11 | touros
# City not found. Skipping...
# Processing Record 49 of Set 11 | balabac
# City not found. Skipping...
# Processing Record 1 of Set 12 | catabola
# City not found. Skipping...
# Processing Record 2 of Set 12 | verkhnevilyuysk
# City not found. Skipping...
# Processing Record 3 of Set 12 | porto torres
# City not found. Skipping...
# Processing Record 4 of Set 12 | tonantins
# City not found. Skipping...
# Processing Record 5 of Set 12 | marsa matruh
# City not found. Skipping...
# Processing Record 6 of Set 12 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 12 | callaway
# City not found. Skipping...
# Processing Record 8 of Set 12 | mezen
# City not found. Skipping...
# Processing Record 9 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 10 of Set 12 | adre
# City not found. Skipping...
# Processing Record 11 of Set 12 | karaton
# City not found. Skipping...
# Processing Record 12 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 13 of Set 12 | ituiutaba
# City not found. Skipping...
# Processing Record 14 of Set 12 | russell
# City not found. Skipping...
# Processing Record 15 of Set 12 | marawi
# City not found. Skipping...
# Processing Record 16 of Set 12 | constitucion
# City not found. Skipping...
# Processing Record 17 of Set 12 | lynn haven
# City not found. Skipping...
# Processing Record 18 of Set 12 | oranjemund
# City not found. Skipping...
# Processing Record 19 of Set 12 | fatikchhari
# City not found. Skipping...
# Processing Record 20 of Set 12 | udachnyy
# City not found. Skipping...
# Processing Record 21 of Set 12 | nouakchott
# City not found. Skipping...
# Processing Record 22 of Set 12 | egvekinot
# City not found. Skipping...
# Processing Record 23 of Set 12 | araouane
# City not found. Skipping...
# Processing Record 24 of Set 12 | keuruu
# City not found. Skipping...
# Processing Record 25 of Set 12 | leshukonskoye
# City not found. Skipping...
# Processing Record 26 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 12 | barcelos
# City not found. Skipping...
# Processing Record 28 of Set 12 | marathon
# City not found. Skipping...
# Processing Record 29 of Set 12 | champerico
# City not found. Skipping...
# Processing Record 30 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 12 | tuatapere
# City not found. Skipping...
# Processing Record 33 of Set 12 | dubai
# City not found. Skipping...
# Processing Record 34 of Set 12 | atikokan
# City not found. Skipping...
# Processing Record 35 of Set 12 | pokhara
# City not found. Skipping...
# Processing Record 36 of Set 12 | nyrob
# City not found. Skipping...
# Processing Record 37 of Set 12 | huangchuan
# City not found. Skipping...
# Processing Record 38 of Set 12 | havre
# City not found. Skipping...
# Processing Record 39 of Set 12 | puri
# City not found. Skipping...
# Processing Record 40 of Set 12 | yemelyanovo
# City not found. Skipping...
# Processing Record 41 of Set 12 | palafrugell
# City not found. Skipping...
# Processing Record 42 of Set 12 | iisalmi
# City not found. Skipping...
# Processing Record 43 of Set 12 | grindavik
# City not found. Skipping...
# Processing Record 44 of Set 12 | kazerun
# City not found. Skipping...
# Processing Record 45 of Set 12 | algiers
# City not found. Skipping...
# Processing Record 46 of Set 12 | kupang
# City not found. Skipping...
# Processing Record 47 of Set 12 | pecos
# City not found. Skipping...
# Processing Record 48 of Set 12 | fukue
# City not found. Skipping...
# Processing Record 49 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 1 of Set 13 | luderitz
# City not found. Skipping...
# Processing Record 2 of Set 13 | vanimo
# City not found. Skipping...
# Processing Record 3 of Set 13 | brigantine
# City not found. Skipping...
# Processing Record 4 of Set 13 | kangaatsiaq
# City not found. Skipping...
# Processing Record 5 of Set 13 | ayagoz
# City not found. Skipping...
# Processing Record 6 of Set 13 | tenenkou
# City not found. Skipping...
# Processing Record 7 of Set 13 | caraquet
# City not found. Skipping...
# Processing Record 8 of Set 13 | luau
# City not found. Skipping...
# Processing Record 9 of Set 13 | tabuk
# City not found. Skipping...
# Processing Record 10 of Set 13 | rudnogorsk
# City not found. Skipping...
# Processing Record 11 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 12 of Set 13 | noumea
# City not found. Skipping...
# Processing Record 13 of Set 13 | sofiyivka
# City not found. Skipping...
# Processing Record 14 of Set 13 | matadi
# City not found. Skipping...
# Processing Record 15 of Set 13 | chicama
# City not found. Skipping...
# Processing Record 16 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 17 of Set 13 | farah
# City not found. Skipping...
# Processing Record 18 of Set 13 | norden
# City not found. Skipping...
# Processing Record 19 of Set 13 | emba
# City not found. Skipping...
# Processing Record 20 of Set 13 | mitu
# City not found. Skipping...
# Processing Record 21 of Set 13 | chauk
# City not found. Skipping...
# Processing Record 22 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 13 | tessalit
# City not found. Skipping...
# Processing Record 24 of Set 13 | sola
# City not found. Skipping...
# Processing Record 25 of Set 13 | nelson bay
# City not found. Skipping...
# Processing Record 26 of Set 13 | mnogovershinnyy
# City not found. Skipping...
# Processing Record 27 of Set 13 | muravlenko
# City not found. Skipping...
# Processing Record 28 of Set 13 | yarada
# City not found. Skipping...
# Processing Record 29 of Set 13 | minsk
# City not found. Skipping...
# Processing Record 30 of Set 13 | stromness
# City not found. Skipping...
# Processing Record 31 of Set 13 | zhigansk
# City not found. Skipping...
# Processing Record 32 of Set 13 | huarmey
# City not found. Skipping...
# Processing Record 33 of Set 13 | koutiala
# City not found. Skipping...
# Processing Record 34 of Set 13 | aksarka
# City not found. Skipping...
# Processing Record 35 of Set 13 | bonavista
# City not found. Skipping...
# Processing Record 36 of Set 13 | yelan-kolenovskiy
# City not found. Skipping...
# Processing Record 37 of Set 13 | kichmengskiy gorodok
# City not found. Skipping...
# Processing Record 38 of Set 13 | yunguyo
# City not found. Skipping...
# Processing Record 39 of Set 13 | north bend
# City not found. Skipping...
# Processing Record 40 of Set 13 | outlook
# City not found. Skipping...
# Processing Record 41 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 42 of Set 13 | axim
# City not found. Skipping...
# Processing Record 43 of Set 13 | xingcheng
# City not found. Skipping...
# Processing Record 44 of Set 13 | tera
# City not found. Skipping...
# Processing Record 45 of Set 13 | dzhebariki-khaya
# City not found. Skipping...
# Processing Record 46 of Set 13 | el balyana
# City not found. Skipping...
# Processing Record 47 of Set 13 | nabire
# City not found. Skipping...
# Processing Record 48 of Set 13 | port hedland
# City not found. Skipping...
# ===========================================================
# Data Retrieval Complete
# ===========================================================

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | touba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | ibra
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | morgan city
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kawalu
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | hjallerup
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | victoria
# Processing Record 22 of Set 1 | rangapara
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | khatanga
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 1 | kota bahru
# Processing Record 29 of Set 1 | rocha
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | umm lajj
# Processing Record 32 of Set 1 | zvenyhorodka
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | ayan
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | mount isa
# Processing Record 42 of Set 1 | beringovskiy
# Processing Record 43 of Set 1 | shu
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | bandarbeyla
# Processing Record 50 of Set 1 | isla vista
# Processing Record 0 of Set 2 | arroyo
# Processing Record 1 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 2 | caimito
# Processing Record 5 of Set 2 | amalapuram
# Processing Record 6 of Set 2 | moree
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | san patricio
# Processing Record 9 of Set 2 | kiunga
# Processing Record 10 of Set 2 | antalaha
# Processing Record 11 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 2 | eureka
# Processing Record 15 of Set 2 | ust-maya
# Processing Record 16 of Set 2 | barraute
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | saint george
# Processing Record 19 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 2 | farafangana
# Processing Record 21 of Set 2 | mporokoso
# Processing Record 22 of Set 2 | leningradskiy
# Processing Record 23 of Set 2 | hamilton
# Processing Record 24 of Set 2 | yumen
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | saldanha
# Processing Record 27 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 2 | shenzhen
# Processing Record 29 of Set 2 | dingle
# Processing Record 30 of Set 2 | labuhan
# Processing Record 31 of Set 2 | isangel
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | zhangjiakou
# Processing Record 34 of Set 2 | olga
# Processing Record 35 of Set 2 | luganville
# Processing Record 36 of Set 2 | jinchang
# Processing Record 37 of Set 2 | lagoa
# Processing Record 38 of Set 2 | strezhevoy
# Processing Record 39 of Set 2 | bauchi
# Processing Record 40 of Set 2 | shimoda
# Processing Record 41 of Set 2 | kieta
# Processing Record 42 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 2 | poum
# Processing Record 44 of Set 2 | san cristobal
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | kruisfontein
# Processing Record 48 of Set 2 | conde
# Processing Record 49 of Set 2 | sal rei
# Processing Record 0 of Set 3 | dikson
# Processing Record 1 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | samarinda
# Processing Record 4 of Set 3 | mwinilunga
# Processing Record 5 of Set 3 | chernyshkovskiy
# Processing Record 6 of Set 3 | takapau
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | kysyl-syr
# Processing Record 9 of Set 3 | butembo
# Processing Record 10 of Set 3 | narsaq
# Processing Record 11 of Set 3 | sao filipe
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | oktyabrskiy
# Processing Record 14 of Set 3 | malanje
# Processing Record 15 of Set 3 | topolog
# Processing Record 16 of Set 3 | bogorodskoye
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | saint-paul
# Processing Record 21 of Set 3 | vanavara
# Processing Record 22 of Set 3 | mitsamiouli
# Processing Record 23 of Set 3 | mar del plata
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | port lincoln
# Processing Record 26 of Set 3 | yuzhno-kurilsk
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | pevek
# Processing Record 30 of Set 3 | yellowknife
# Processing Record 31 of Set 3 | flin flon
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | buraydah
# Processing Record 34 of Set 3 | dauphin
# Processing Record 35 of Set 3 | estelle
# Processing Record 36 of Set 3 | shonguy
# Processing Record 37 of Set 3 | berlevag
# Processing Record 38 of Set 3 | boyuibe
# Processing Record 39 of Set 3 | airai
# Processing Record 40 of Set 3 | bambous virieux
# Processing Record 41 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 3 | ikalamavony
# Processing Record 43 of Set 3 | sur
# Processing Record 44 of Set 3 | arraial do cabo
# Processing Record 45 of Set 3 | coihueco
# Processing Record 46 of Set 3 | bubaque
# Processing Record 47 of Set 3 | codrington
# Processing Record 48 of Set 3 | new norfolk
# Processing Record 49 of Set 3 | laguna
# Processing Record 0 of Set 4 | port keats
# Processing Record 1 of Set 4 | cannington
# Processing Record 2 of Set 4 | hambantota
# Processing Record 3 of Set 4 | sorland
# Processing Record 4 of Set 4 | trelew
# Processing Record 5 of Set 4 | kumbhraj
# Processing Record 6 of Set 4 | san blas
# Processing Record 7 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 4 | buala
# Processing Record 9 of Set 4 | ocos
# Processing Record 10 of Set 4 | vestmannaeyjar
# Processing Record 11 of Set 4 | ponta do sol
# Processing Record 12 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 4 | kalaleh
# Processing Record 14 of Set 4 | tornio
# Processing Record 15 of Set 4 | bar harbor
# Processing Record 16 of Set 4 | jiangyou
# Processing Record 17 of Set 4 | xingyi
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | misratah
# Processing Record 20 of Set 4 | haines junction
# Processing Record 21 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 4 | cabo san lucas
# Processing Record 23 of Set 4 | elizabeth city
# Processing Record 24 of Set 4 | baiyin
# Processing Record 25 of Set 4 | matara
# Processing Record 26 of Set 4 | ambilobe
# Processing Record 27 of Set 4 | yelizovo
# Processing Record 28 of Set 4 | messina
# Processing Record 29 of Set 4 | bajo baudo
# City not found. Skipping...
# Processing Record 30 of Set 4 | puerto ayora
# Processing Record 31 of Set 4 | malindi
# Processing Record 32 of Set 4 | plettenberg bay
# Processing Record 33 of Set 4 | lorengau
# Processing Record 34 of Set 4 | hay river
# Processing Record 35 of Set 4 | kodiak
# Processing Record 36 of Set 4 | chimbote
# Processing Record 37 of Set 4 | kanor
# Processing Record 38 of Set 4 | san pedro de uraba
# Processing Record 39 of Set 4 | taphan hin
# Processing Record 40 of Set 4 | upernavik
# Processing Record 41 of Set 4 | matagami
# Processing Record 42 of Set 4 | terme
# Processing Record 43 of Set 4 | coria
# Processing Record 44 of Set 4 | pallasovka
# Processing Record 45 of Set 4 | asyut
# Processing Record 46 of Set 4 | cockburn town
# Processing Record 47 of Set 4 | osypenko
# Processing Record 48 of Set 4 | sioux lookout
# Processing Record 49 of Set 4 | gotsu
# Processing Record 0 of Set 5 | abadan
# Processing Record 1 of Set 5 | lewistown
# Processing Record 2 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | ostersund
# Processing Record 5 of Set 5 | calafell
# Processing Record 6 of Set 5 | panguna
# Processing Record 7 of Set 5 | nantucket
# Processing Record 8 of Set 5 | la ronge
# Processing Record 9 of Set 5 | harper
# Processing Record 10 of Set 5 | monte azul
# Processing Record 11 of Set 5 | binga
# Processing Record 12 of Set 5 | saskylakh
# Processing Record 13 of Set 5 | ushirombo
# Processing Record 14 of Set 5 | guerrero negro
# Processing Record 15 of Set 5 | sobradinho
# Processing Record 16 of Set 5 | saint-leu
# Processing Record 17 of Set 5 | rabo de peixe
# Processing Record 18 of Set 5 | cabedelo
# Processing Record 19 of Set 5 | esperance
# Processing Record 20 of Set 5 | grand gaube
# Processing Record 21 of Set 5 | kirakira
# Processing Record 22 of Set 5 | we
# City not found. Skipping...
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | mosetse
# Processing Record 25 of Set 5 | storforshei
# Processing Record 26 of Set 5 | nuuk
# Processing Record 27 of Set 5 | iqaluit
# Processing Record 28 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 5 | lang suan
# Processing Record 30 of Set 5 | carnarvon
# Processing Record 31 of Set 5 | atuona
# Processing Record 32 of Set 5 | tiksi
# Processing Record 33 of Set 5 | kasempa
# Processing Record 34 of Set 5 | maldonado
# Processing Record 35 of Set 5 | ostrovnoy
# Processing Record 36 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 5 | tacarigua
# Processing Record 38 of Set 5 | kahului
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | sitka
# Processing Record 41 of Set 5 | maryborough
# Processing Record 42 of Set 5 | belmonte
# Processing Record 43 of Set 5 | nalut
# Processing Record 44 of Set 5 | ginda
# Processing Record 45 of Set 5 | iquique
# Processing Record 46 of Set 5 | boa vista
# Processing Record 47 of Set 5 | hofn
# Processing Record 48 of Set 5 | fowa
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 0 of Set 6 | rio gallegos
# Processing Record 1 of Set 6 | saint-pierre
# Processing Record 2 of Set 6 | hargeysa
# Processing Record 3 of Set 6 | ormara
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | nosy varika
# Processing Record 6 of Set 6 | lanzhou
# Processing Record 7 of Set 6 | umm kaddadah
# Processing Record 8 of Set 6 | muyezerskiy
# Processing Record 9 of Set 6 | boyolangu
# Processing Record 10 of Set 6 | tuatapere
# Processing Record 11 of Set 6 | yamada
# Processing Record 12 of Set 6 | makokou
# Processing Record 13 of Set 6 | ust-kuyga
# Processing Record 14 of Set 6 | teahupoo
# Processing Record 15 of Set 6 | yele
# Processing Record 16 of Set 6 | moose factory
# Processing Record 17 of Set 6 | baglung
# Processing Record 18 of Set 6 | cidreira
# Processing Record 19 of Set 6 | tairua
# Processing Record 20 of Set 6 | souillac
# Processing Record 21 of Set 6 | salta
# Processing Record 22 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 6 | vung tau
# Processing Record 24 of Set 6 | ucluelet
# Processing Record 25 of Set 6 | aksarka
# Processing Record 26 of Set 6 | fairbanks
# Processing Record 27 of Set 6 | bonavista
# Processing Record 28 of Set 6 | kayerkan
# Processing Record 29 of Set 6 | chute-aux-outardes
# Processing Record 30 of Set 6 | leh
# Processing Record 31 of Set 6 | celestun
# Processing Record 32 of Set 6 | anderson
# Processing Record 33 of Set 6 | maldaeni
# Processing Record 34 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 6 | kaitong
# Processing Record 36 of Set 6 | kondopoga
# Processing Record 37 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 6 | singkang
# Processing Record 39 of Set 6 | kyra
# Processing Record 40 of Set 6 | torbay
# Processing Record 41 of Set 6 | margate
# Processing Record 42 of Set 6 | faanui
# Processing Record 43 of Set 6 | hasaki
# Processing Record 44 of Set 6 | altay
# Processing Record 45 of Set 6 | akureyri
# Processing Record 46 of Set 6 | kurumkan
# Processing Record 47 of Set 6 | miracema do tocantins
# Processing Record 48 of Set 6 | ugoofaaru
# Processing Record 49 of Set 6 | ahipara
# Processing Record 0 of Set 7 | sorkjosen
# Processing Record 1 of Set 7 | talnakh
# Processing Record 2 of Set 7 | milkovo
# Processing Record 3 of Set 7 | vanimo
# Processing Record 4 of Set 7 | majene
# Processing Record 5 of Set 7 | alta floresta
# Processing Record 6 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 7 | bluffton
# Processing Record 8 of Set 7 | lima
# Processing Record 9 of Set 7 | adrar
# Processing Record 10 of Set 7 | katangli
# Processing Record 11 of Set 7 | fort nelson
# Processing Record 12 of Set 7 | qinggang
# Processing Record 13 of Set 7 | aklavik
# Processing Record 14 of Set 7 | paracuru
# Processing Record 15 of Set 7 | bathsheba
# Processing Record 16 of Set 7 | pacifica
# Processing Record 17 of Set 7 | sept-iles
# Processing Record 18 of Set 7 | bereda
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | padang
# Processing Record 21 of Set 7 | honningsvag
# Processing Record 22 of Set 7 | pilar do sul
# Processing Record 23 of Set 7 | merauke
# Processing Record 24 of Set 7 | phonhong
# Processing Record 25 of Set 7 | zhuhai
# Processing Record 26 of Set 7 | havre-saint-pierre
# Processing Record 27 of Set 7 | san quintin
# Processing Record 28 of Set 7 | neiafu
# Processing Record 29 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 7 | weligama
# Processing Record 32 of Set 7 | gat
# Processing Record 33 of Set 7 | loiza
# Processing Record 34 of Set 7 | pacific grove
# Processing Record 35 of Set 7 | gawler
# Processing Record 36 of Set 7 | mount gambier
# Processing Record 37 of Set 7 | college
# Processing Record 38 of Set 7 | tomatlan
# Processing Record 39 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 7 | vostok
# Processing Record 41 of Set 7 | talaya
# Processing Record 42 of Set 7 | somanda
# Processing Record 43 of Set 7 | longyearbyen
# Processing Record 44 of Set 7 | zhigansk
# Processing Record 45 of Set 7 | thinadhoo
# Processing Record 46 of Set 7 | aripuana
# Processing Record 47 of Set 7 | brownsville
# Processing Record 48 of Set 7 | yenagoa
# Processing Record 49 of Set 7 | okhotsk
# Processing Record 0 of Set 8 | astara
# Processing Record 1 of Set 8 | lac-megantic
# Processing Record 2 of Set 8 | mutare
# Processing Record 3 of Set 8 | asau
# Processing Record 4 of Set 8 | acarau
# Processing Record 5 of Set 8 | praia
# Processing Record 6 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 7 of Set 8 | balabac
# Processing Record 8 of Set 8 | porto novo
# Processing Record 9 of Set 8 | los llanos de aridane
# Processing Record 10 of Set 8 | shelburne
# Processing Record 11 of Set 8 | coihaique
# Processing Record 12 of Set 8 | montepuez
# Processing Record 13 of Set 8 | batagay
# Processing Record 14 of Set 8 | geraldton
# Processing Record 15 of Set 8 | port-cartier
# Processing Record 16 of Set 8 | tsumeb
# Processing Record 17 of Set 8 | meulaboh
# Processing Record 18 of Set 8 | korla
# Processing Record 19 of Set 8 | chapais
# Processing Record 20 of Set 8 | bozeman
# Processing Record 21 of Set 8 | muli
# Processing Record 22 of Set 8 | yar-sale
# Processing Record 23 of Set 8 | northam
# Processing Record 24 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 8 | hervey bay
# Processing Record 26 of Set 8 | uchiza
# Processing Record 27 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 8 | porto walter
# Processing Record 29 of Set 8 | horsham
# Processing Record 30 of Set 8 | maraa
# Processing Record 31 of Set 8 | vila franca do campo
# Processing Record 32 of Set 8 | garoua
# Processing Record 33 of Set 8 | kampot
# Processing Record 34 of Set 8 | marawi
# Processing Record 35 of Set 8 | egvekinot
# Processing Record 36 of Set 8 | liverpool
# Processing Record 37 of Set 8 | sanandaj
# Processing Record 38 of Set 8 | tabou
# Processing Record 39 of Set 8 | kavieng
# Processing Record 40 of Set 8 | cap malheureux
# Processing Record 41 of Set 8 | logan
# Processing Record 42 of Set 8 | klaksvik
# Processing Record 43 of Set 8 | sisimiut
# Processing Record 44 of Set 8 | whyalla
# Processing Record 45 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 8 | hailar
# Processing Record 47 of Set 8 | ajdabiya
# Processing Record 48 of Set 8 | saint-georges
# Processing Record 49 of Set 8 | hoopstad
# Processing Record 0 of Set 9 | emerald
# Processing Record 1 of Set 9 | flinders
# Processing Record 2 of Set 9 | fare
# Processing Record 3 of Set 9 | carballo
# Processing Record 4 of Set 9 | tan an
# Processing Record 5 of Set 9 | allapalli
# Processing Record 6 of Set 9 | santa maria
# Processing Record 7 of Set 9 | sesheke
# Processing Record 8 of Set 9 | tecoanapa
# Processing Record 9 of Set 9 | gaspe
# Processing Record 10 of Set 9 | carutapera
# Processing Record 11 of Set 9 | toba
# Processing Record 12 of Set 9 | neu wulmstorf
# Processing Record 13 of Set 9 | wakkanai
# Processing Record 14 of Set 9 | pierre
# Processing Record 15 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 9 | arica
# Processing Record 17 of Set 9 | nsoko
# Processing Record 18 of Set 9 | krasnoarmeysk
# Processing Record 19 of Set 9 | juneau
# Processing Record 20 of Set 9 | chateauroux
# Processing Record 21 of Set 9 | kloulklubed
# Processing Record 22 of Set 9 | jiaozuo
# Processing Record 23 of Set 9 | tuburan
# Processing Record 24 of Set 9 | teknaf
# Processing Record 25 of Set 9 | makakilo city
# Processing Record 26 of Set 9 | sanski most
# Processing Record 27 of Set 9 | kaitangata
# Processing Record 28 of Set 9 | hengyang
# Processing Record 29 of Set 9 | talcahuano
# Processing Record 30 of Set 9 | arawa
# Processing Record 31 of Set 9 | mercedes
# Processing Record 32 of Set 9 | chengde
# Processing Record 33 of Set 9 | stokmarknes
# Processing Record 34 of Set 9 | kalpi
# Processing Record 35 of Set 9 | valdosta
# Processing Record 36 of Set 9 | chiampo
# Processing Record 37 of Set 9 | marsa matruh
# Processing Record 38 of Set 9 | nome
# Processing Record 39 of Set 9 | careva cuprija
# Processing Record 40 of Set 9 | port macquarie
# Processing Record 41 of Set 9 | lokosovo
# Processing Record 42 of Set 9 | rawson
# Processing Record 43 of Set 9 | skelleftea
# Processing Record 44 of Set 9 | nakasongola
# Processing Record 45 of Set 9 | lompoc
# Processing Record 46 of Set 9 | nizwa
# Processing Record 47 of Set 9 | sabang
# Processing Record 48 of Set 9 | noumea
# Processing Record 49 of Set 9 | ruteng
# Processing Record 0 of Set 10 | deputatskiy
# Processing Record 1 of Set 10 | sola
# Processing Record 2 of Set 10 | nikolayevka
# Processing Record 3 of Set 10 | tabas
# Processing Record 4 of Set 10 | qianan
# Processing Record 5 of Set 10 | vila velha
# Processing Record 6 of Set 10 | isperih
# Processing Record 7 of Set 10 | hamina
# Processing Record 8 of Set 10 | turukhansk
# Processing Record 9 of Set 10 | dodge city
# Processing Record 10 of Set 10 | espinosa
# Processing Record 11 of Set 10 | hayden
# Processing Record 12 of Set 10 | maniitsoq
# Processing Record 13 of Set 10 | camacha
# Processing Record 14 of Set 10 | vikramasingapuram
# Processing Record 15 of Set 10 | nanortalik
# Processing Record 16 of Set 10 | asmar
# Processing Record 17 of Set 10 | shingu
# Processing Record 18 of Set 10 | mattru
# Processing Record 19 of Set 10 | belgaum
# Processing Record 20 of Set 10 | taoudenni
# Processing Record 21 of Set 10 | lata
# Processing Record 22 of Set 10 | sao felix do xingu
# Processing Record 23 of Set 10 | rayachoti
# Processing Record 24 of Set 10 | sakakah
# Processing Record 25 of Set 10 | chokurdakh
# Processing Record 26 of Set 10 | konibodom
# Processing Record 27 of Set 10 | mabaruma
# Processing Record 28 of Set 10 | eyl
# Processing Record 29 of Set 10 | astoria
# Processing Record 30 of Set 10 | samarai
# Processing Record 31 of Set 10 | derzhavinsk
# Processing Record 32 of Set 10 | high level
# Processing Record 33 of Set 10 | opuwo
# Processing Record 34 of Set 10 | salinopolis
# Processing Record 35 of Set 10 | waipawa
# Processing Record 36 of Set 10 | aksu
# Processing Record 37 of Set 10 | saint paul
# Processing Record 38 of Set 10 | anadyr
# Processing Record 39 of Set 10 | inhambane
# Processing Record 40 of Set 10 | sakaiminato
# Processing Record 41 of Set 10 | santa cruz
# Processing Record 42 of Set 10 | russkaya polyana
# Processing Record 43 of Set 10 | beipiao
# Processing Record 44 of Set 10 | srednekolymsk
# Processing Record 45 of Set 10 | tripoli
# Processing Record 46 of Set 10 | swift current
# Processing Record 47 of Set 10 | quatre cocos
# Processing Record 48 of Set 10 | corbelia
# Processing Record 49 of Set 10 | roma
# Processing Record 0 of Set 11 | north bend
# Processing Record 1 of Set 11 | kiama
# Processing Record 2 of Set 11 | muroto
# Processing Record 3 of Set 11 | smidovich
# Processing Record 4 of Set 11 | conceicao do araguaia
# Processing Record 5 of Set 11 | ponta pora
# Processing Record 6 of Set 11 | bogatoye
# Processing Record 7 of Set 11 | muravlenko
# Processing Record 8 of Set 11 | avera
# Processing Record 9 of Set 11 | qiongshan
# Processing Record 10 of Set 11 | saint-augustin
# Processing Record 11 of Set 11 | yilan
# Processing Record 12 of Set 11 | port blair
# Processing Record 13 of Set 11 | shakawe
# Processing Record 14 of Set 11 | alghero
# Processing Record 15 of Set 11 | bud
# Processing Record 16 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | nouadhibou
# Processing Record 19 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 11 | florianopolis
# Processing Record 21 of Set 11 | linjiang
# Processing Record 22 of Set 11 | krasnoselkup
# Processing Record 23 of Set 11 | maloy
# Processing Record 24 of Set 11 | itoman
# Processing Record 25 of Set 11 | aykhal
# Processing Record 26 of Set 11 | kalmeshwar
# Processing Record 27 of Set 11 | baracoa
# Processing Record 28 of Set 11 | gairo
# Processing Record 29 of Set 11 | seymchan
# Processing Record 30 of Set 11 | klaebu
# Processing Record 31 of Set 11 | beira
# Processing Record 32 of Set 11 | lebanon
# Processing Record 33 of Set 11 | cayenne
# Processing Record 34 of Set 11 | viedma
# Processing Record 35 of Set 11 | massape
# Processing Record 36 of Set 11 | arlit
# Processing Record 37 of Set 11 | soe
# Processing Record 38 of Set 11 | kempsey
# Processing Record 39 of Set 11 | saint-jean-port-joli
# Processing Record 40 of Set 11 | coahuayana
# Processing Record 41 of Set 11 | sao jose da coroa grande
# Processing Record 42 of Set 11 | kutum
# Processing Record 43 of Set 11 | las cruces
# Processing Record 44 of Set 11 | manta
# Processing Record 45 of Set 11 | mayumba
# Processing Record 46 of Set 11 | union
# Processing Record 47 of Set 11 | brae
# Processing Record 48 of Set 11 | otane
# Processing Record 49 of Set 11 | rio muerto
# Processing Record 0 of Set 12 | polunochnoye
# Processing Record 1 of Set 12 | artigas
# Processing Record 2 of Set 12 | lalibela
# Processing Record 3 of Set 12 | castelo branco
# Processing Record 4 of Set 12 | moron
# Processing Record 5 of Set 12 | naze
# Processing Record 6 of Set 12 | natal
# Processing Record 7 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 8 of Set 12 | walvis bay
# Processing Record 9 of Set 12 | tarbagatay
# Processing Record 10 of Set 12 | kamenka
# Processing Record 11 of Set 12 | qaqortoq
# Processing Record 12 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 13 of Set 12 | karratha
# Processing Record 14 of Set 12 | paita
# Processing Record 15 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 12 | kaohsiung
# Processing Record 17 of Set 12 | shache
# Processing Record 18 of Set 12 | divnoye
# Processing Record 19 of Set 12 | barra dos coqueiros
# Processing Record 20 of Set 12 | provideniya
# Processing Record 21 of Set 12 | norman wells
# Processing Record 22 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 23 of Set 12 | follonica
# Processing Record 24 of Set 12 | verkhoyansk
# Processing Record 25 of Set 12 | henties bay
# Processing Record 26 of Set 12 | kudahuvadhoo
# Processing Record 27 of Set 12 | bandundu
# Processing Record 28 of Set 12 | cascais
# Processing Record 29 of Set 12 | dickinson
# Processing Record 30 of Set 12 | san benito
# Processing Record 31 of Set 12 | kenai
# Processing Record 32 of Set 12 | rio pardo de minas
# Processing Record 33 of Set 12 | erzin
# Processing Record 34 of Set 12 | san carlos del zulia
# Processing Record 35 of Set 12 | kyshtovka
# Processing Record 36 of Set 12 | zima
# Processing Record 37 of Set 12 | khandbari
# Processing Record 38 of Set 12 | salyan
# Processing Record 39 of Set 12 | saint-joseph
# Processing Record 40 of Set 12 | tocopilla
# Processing Record 41 of Set 12 | ust-nera
# Processing Record 42 of Set 12 | yangambi
# Processing Record 43 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 12 | shirakamut
# Processing Record 45 of Set 12 | berezovyy
# Processing Record 46 of Set 12 | dunedin
# Processing Record 47 of Set 12 | bonthe
# Processing Record 48 of Set 12 | sijunjung
# Processing Record 49 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 0 of Set 13 | atar
# Processing Record 1 of Set 13 | fayaoue
# Processing Record 2 of Set 13 | san lawrenz
# Processing Record 3 of Set 13 | lashio
# Processing Record 4 of Set 13 | shenjiamen
# Processing Record 5 of Set 13 | longonjo
# Processing Record 6 of Set 13 | erenhot
# Processing Record 7 of Set 13 | prior lake
# Processing Record 8 of Set 13 | sao gabriel da cachoeira
# Processing Record 9 of Set 13 | billings
# Processing Record 10 of Set 13 | kalmunai
# Processing Record 11 of Set 13 | meadow lake
# Processing Record 12 of Set 13 | littleton
# Processing Record 13 of Set 13 | soloneshnoye
# Processing Record 14 of Set 13 | pravia
# Processing Record 15 of Set 13 | portland
# Processing Record 16 of Set 13 | singleton
# Processing Record 17 of Set 13 | karasjok
# Processing Record 18 of Set 13 | yaan
# Processing Record 19 of Set 13 | palauig
# Processing Record 20 of Set 13 | pochutla
# Processing Record 21 of Set 13 | obluche
# City not found. Skipping...
# Processing Record 22 of Set 13 | macusani
# Processing Record 23 of Set 13 | kaffrine
# Processing Record 24 of Set 13 | diamantina
# Processing Record 25 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 13 | middlebury
# Processing Record 27 of Set 13 | anju
# Processing Record 28 of Set 13 | la rioja
# Processing Record 29 of Set 13 | alofi
# Processing Record 30 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 13 | palu
# Processing Record 32 of Set 13 | kuusamo
# Processing Record 33 of Set 13 | cap-aux-meules
# Processing Record 34 of Set 13 | palencia
# Processing Record 35 of Set 13 | maues
# Processing Record 36 of Set 13 | lososina
# Processing Record 37 of Set 13 | gorontalo
# Processing Record 38 of Set 13 | antalya
# Processing Record 39 of Set 13 | port hueneme
# Processing Record 40 of Set 13 | puerto colombia
# Processing Record 41 of Set 13 | sapele
# Processing Record 42 of Set 13 | bend
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Convert Raw Data to DataFrame
#=======================================================================================
updated_weather_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country_id,
    "Date": date,
})

#Getting rid of any cities that could not be found(skipped) using the dropna function
updated_weather_df = weather_df.dropna(how="any")

# %%
#Export the city data into a .csv.
#================================================
#updated_weather_df.to_csv("C:/Users/DeferentAtom94/OneDrive/Desktop/Resources/Pandas_Challenge/weather_data.csv", index=False)
#Display the DataFrame

updated_weather_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
u

# %%
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a scatter plot for latitude vs max temperature.
x_values = updated_weather_df['Lat']
y_values = updated_weather_df['Max Temp']
fig1, ax1 = plt.subplots(figsize=(14,10))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude', fontsize=16)
plt.ylabel('Max Temperature (F)', fontsize=16)
plt.title(f"City Latitude vs Max Temperature",fontsize=22)
plt.grid()
#plt.savefig("./output_data/latitude_vs_temperature.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a scatter plot for latitude vs humidity.
x_values = updated_weather_df['Lat']
y_values = updated_weather_df['Humidity']
fig1, ax1 = plt.subplots(figsize=(14, 10))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude',fontsize=16)
plt.ylabel('Humidity (%)',fontsize=16)
plt.title(f'Latitude vs Humidity',fontsize=22)
plt.grid()
#plt.savefig("./output_data/latitude_vs_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot for latitude vs cloudiness.
x_values = updated_weather_df['Lat']
y_values = updated_weather_df['Cloudiness']
fig1, ax1 = plt.subplots(figsize=(14,10))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude', fontsize=16)
plt.ylabel('Cloudiness (%)', fontsize=16)
plt.title(f'Latitude vs Cloudiness',fontsize=22 )
plt.grid()
#plt.savefig("./output_data/latitude_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot for latitude vs wind speed.
x_values = updated_weather_df['Lat']
y_values = updated_weather_df['Wind Speed']
fig1, ax1 = plt.subplots(figsize=(14,10))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude',fontsize=16 )
plt.ylabel('Wind Speed (mph)', fontsize=16)
plt.title(f'Latitude vs Wind Speed', fontsize=22)
plt.grid()
#plt.savefig("./output_data/latitude_vs_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Linear Regression
#===================================================================================================
def  regression_plot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    fig1, ax1 = plt.subplots(figsize=(10,8))
    plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
    plt.xlabel(x_label,fontsize = 14)
    plt.ylabel(y_label,fontsize = 14)
    if ylim is not None:
        plt.ylim(0, ylim)
    
    
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} ",fontsize = 16)
    
    plt.annotate(line_eq,xy=(10, 50),fontsize=22,xycoords='data',xytext=(0.4, 0.4),\
                 textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    
    plt.annotate(line_eq,xy=(-50, 40),fontsize=22,xycoords='data',xytext=(0.4, 0.3),\
                 textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    
    plt.annotate(line_eq,xy=(10, 25),fontsize=22,xycoords='data',xytext=(0.4, 0.4),\
                 textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    
    # Print r square value
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    return plt.plot(x_values,regress_values,"r-")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create Northern and Southern Hemisphere DataFrames
#=======================================================================================
northern_hemisphere_weather_df = updated_weather_df.loc[updated_weather_df["Lat"] >= 0]
southern_hemisphere_weather_df = updated_weather_df.loc[updated_weather_df["Lat"] < 0]

# %%
# Create a scatter plot for latitude vs max temp (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Max Temp']
regression_plot(x_values, y_values, "Lat", "Max Temp (F)", "Northern",(0, 0))
#plt.savefig("./output_data/Northern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.6644951847801372
# The correlation between both factors is -0.82

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs cloudiness (southern hemisphere)
#=======================================================================================
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
regression_plot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))

#plt.savefig("./output_data/southern_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.050144508564721905
# The correlation between both factors is 0.22

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs humditiy (northern hemisphere)
#=================================================================================
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Humidity']
regression_plot(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(40, 20))
#plt.savefig("./output_data/Northern_Hemisphere_Humidity_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.010729512501511105
# The correlation between both factors is 0.1

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs humditiy (southern hemisphere)
#===================================================================================================
x_values1 = southern_hemisphere_weather_df['Lat']
y_values1 = southern_hemisphere_weather_df['Humidity']
regression_plot(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(40, 20), 150)
# plt.savefig("./output_data/southern_humudity_Hemisphere_Max_lat_lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.010729512501511105
# The correlation between both factors is 0.1

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs cloudiness (northern hemisphere)
#========================================================================================
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Cloudiness']
regression_plot(x_values, y_values, "Latitude", "Cloudiness(%)", "Northern",(30, 50))

#plt.savefig("./output_data/Northern Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.007627485925231671
# The correlation between both factors is -0.09

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs cloudiness (southern hemisphere)
#================================================================================
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
regression_plot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))

#plt.savefig("./output_data/Southern_Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.050144508564721905
# The correlation between both factors is 0.22

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs wind speed(northern hemisphere)
#==================================================================================================
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Wind Speed']
regression_plot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))

#plt.savefig("./output_data/Northern_Hemisphere_Wind_Speed_Latitude_Lin.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.011478610492563554
# The correlation between both factors is 0.11

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs wind speed (southern hemisphere)
#===========================================================================================
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Wind Speed']
regression_plot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25), ylim=40)

#plt.savefig("./output_data/Southern_Hemisphere_Wind_Speed_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.1040436814752203
# The correlation between both factors is -0.32

# %%
# Out:
# The r-value is: 0.017128274759839232
