# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from config import wthrapikey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
weather_df = pd.read_csv("C:/Users/DeferentAtom94/OneDrive/Desktop/Resources/Pandas_Challenge/cities1.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Define Url and units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Create query Url
query_url = f"{url}appid={wthrapikey}&units={units}&q="

# %%
#Creating Empty Lists to hold API response information
#===========================================================================
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country_id = []
date = []

# %%
#Create a loop through the list of cites
#===================================================================
#Emulating the example, start with the following statement:

print("Beginning Data Retrieval")
print("================================================")

count = 0
set = 1

#Create For loop while using the enumerate function
#Enumerate() method adds a counter to an iterable and returns it in a form of enumerating object. 
#This enumerated object can then be used directly for loops or converted into a list of tuples using the list() method.

for index, city in enumerate(cities):
    count = count + 1
    #Trying to avoid incurring call rate limits set up a counter to sleep after getting data for the first 50 cities.
    #Using time.sleep() to space out the API calls. Which is why I'm guessing they added "import time" to the starter code
    # dependencies.
    #if statement
    if count == 50:
        count = 1
        set = set + 1
        time.sleep(10)
        
    #Now to print the statement for outcomes using the example that was given in the starter code.
    print(f"Processing Record {count} of Set {set} | {city}")
    
    #Present the try statement requesting data from the url + city variable and append to the empty lists
    try:
        response = requests.get(url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main'][temp_max])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country_id.append(response['sys']['country'])
        date.append(response['dt'])
        
    #Create a except error statement so that the code continues to run even if an error occurs.
    #Print error statement emulating the example from the starter code
    except KeyError:
        print("City not found. Skipping...")
    #In Python, NumPy NAN stands for not a number
    # and is defined as a substitute for declaring value which are numerical values
    # that are missing values in an array as NumPy is used to deal with arrays in Python
    # and this can be initialized using numpy.  
    
        lat.append(np.nan)
        lng.append(np.nan)
        max_temp.append(np.nan)
        humidity.append(np.nan)
        cloudiness.append(np.nan)
        wind_speed.append(np.nan)
        country_id.append(np.nan)
        date.append(np.nan)
        
#Print ending statement and spacers emulating the example from the starter code  
print("===========================================================") 
print("Data Retrieval Complete")
print("===========================================================")
# Out:
# Beginning Data Retrieval
# ================================================
# Processing Record 1 of Set 1 | poronaysk
# City not found. Skipping...
# Processing Record 2 of Set 1 | ranong
# City not found. Skipping...
# Processing Record 3 of Set 1 | albany
# City not found. Skipping...
# Processing Record 4 of Set 1 | nuuk
# City not found. Skipping...
# Processing Record 5 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 6 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 7 of Set 1 | tasiilaq
# City not found. Skipping...
# Processing Record 8 of Set 1 | sabha
# City not found. Skipping...
# Processing Record 9 of Set 1 | darnah
# City not found. Skipping...
# Processing Record 10 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 11 of Set 1 | ciudad bolivar
# City not found. Skipping...
# Processing Record 12 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 13 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 14 of Set 1 | tiksi
# City not found. Skipping...
# Processing Record 15 of Set 1 | pierre
# City not found. Skipping...
# Processing Record 16 of Set 1 | kuntaur
# City not found. Skipping...
# Processing Record 17 of Set 1 | hermanus
# City not found. Skipping...
# Processing Record 18 of Set 1 | leningradskiy
# City not found. Skipping...
# Processing Record 19 of Set 1 | tura
# City not found. Skipping...
# Processing Record 20 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 21 of Set 1 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 1 | georgetown
# City not found. Skipping...
# Processing Record 23 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 24 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 25 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 26 of Set 1 | dayong
# City not found. Skipping...
# Processing Record 27 of Set 1 | chuy
# City not found. Skipping...
# Processing Record 28 of Set 1 | butaritari
# City not found. Skipping...
# Processing Record 29 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 30 of Set 1 | soyo
# City not found. Skipping...
# Processing Record 31 of Set 1 | geraldton
# City not found. Skipping...
# Processing Record 32 of Set 1 | sheksna
# City not found. Skipping...
# Processing Record 33 of Set 1 | mangrol
# City not found. Skipping...
# Processing Record 34 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 35 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 36 of Set 1 | aswan
# City not found. Skipping...
# Processing Record 37 of Set 1 | coquimbo
# City not found. Skipping...
# Processing Record 38 of Set 1 | tromso
# City not found. Skipping...
# Processing Record 39 of Set 1 | baringo
# City not found. Skipping...
# Processing Record 40 of Set 1 | caruray
# City not found. Skipping...
# Processing Record 41 of Set 1 | nikolskoye
# City not found. Skipping...
# Processing Record 42 of Set 1 | sidi ali
# City not found. Skipping...
# Processing Record 43 of Set 1 | talavera de la reina
# City not found. Skipping...
# Processing Record 44 of Set 1 | vardo
# City not found. Skipping...
# Processing Record 45 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 46 of Set 1 | folkestone
# City not found. Skipping...
# Processing Record 47 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 48 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 49 of Set 1 | grindavik
# City not found. Skipping...
# Processing Record 1 of Set 2 | talnakh
# City not found. Skipping...
# Processing Record 2 of Set 2 | tevriz
# City not found. Skipping...
# Processing Record 3 of Set 2 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 4 of Set 2 | rocha
# City not found. Skipping...
# Processing Record 5 of Set 2 | deputatskiy
# City not found. Skipping...
# Processing Record 6 of Set 2 | torbay
# City not found. Skipping...
# Processing Record 7 of Set 2 | ancud
# City not found. Skipping...
# Processing Record 8 of Set 2 | rikitea
# City not found. Skipping...
# Processing Record 9 of Set 2 | nouadhibou
# City not found. Skipping...
# Processing Record 10 of Set 2 | avarua
# City not found. Skipping...
# Processing Record 11 of Set 2 | batemans bay
# City not found. Skipping...
# Processing Record 12 of Set 2 | sola
# City not found. Skipping...
# Processing Record 13 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 14 of Set 2 | barrow
# City not found. Skipping...
# Processing Record 15 of Set 2 | jamestown
# City not found. Skipping...
# Processing Record 16 of Set 2 | ulladulla
# City not found. Skipping...
# Processing Record 17 of Set 2 | natori
# City not found. Skipping...
# Processing Record 18 of Set 2 | narsaq
# City not found. Skipping...
# Processing Record 19 of Set 2 | yambio
# City not found. Skipping...
# Processing Record 20 of Set 2 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 21 of Set 2 | zary
# City not found. Skipping...
# Processing Record 22 of Set 2 | pokosnoye
# City not found. Skipping...
# Processing Record 23 of Set 2 | baruun-urt
# City not found. Skipping...
# Processing Record 24 of Set 2 | bathsheba
# City not found. Skipping...
# Processing Record 25 of Set 2 | nabire
# City not found. Skipping...
# Processing Record 26 of Set 2 | mar del plata
# City not found. Skipping...
# Processing Record 27 of Set 2 | hithadhoo
# City not found. Skipping...
# Processing Record 28 of Set 2 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 29 of Set 2 | vestmanna
# City not found. Skipping...
# Processing Record 30 of Set 2 | gornyy
# City not found. Skipping...
# Processing Record 31 of Set 2 | hilo
# City not found. Skipping...
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | lebu
# City not found. Skipping...
# Processing Record 35 of Set 2 | andenes
# City not found. Skipping...
# Processing Record 36 of Set 2 | kirakira
# City not found. Skipping...
# Processing Record 37 of Set 2 | kodiak
# City not found. Skipping...
# Processing Record 38 of Set 2 | coahuayana
# City not found. Skipping...
# Processing Record 39 of Set 2 | whitehorse
# City not found. Skipping...
# Processing Record 40 of Set 2 | bor
# City not found. Skipping...
# Processing Record 41 of Set 2 | airai
# City not found. Skipping...
# Processing Record 42 of Set 2 | tupik
# City not found. Skipping...
# Processing Record 43 of Set 2 | esperance
# City not found. Skipping...
# Processing Record 44 of Set 2 | esso
# City not found. Skipping...
# Processing Record 45 of Set 2 | benguela
# City not found. Skipping...
# Processing Record 46 of Set 2 | ostersund
# City not found. Skipping...
# Processing Record 47 of Set 2 | arraial do cabo
# City not found. Skipping...
# Processing Record 48 of Set 2 | balabac
# City not found. Skipping...
# Processing Record 49 of Set 2 | portland
# City not found. Skipping...
# Processing Record 1 of Set 3 | pevek
# City not found. Skipping...
# Processing Record 2 of Set 3 | lagoa
# City not found. Skipping...
# Processing Record 3 of Set 3 | cordoba
# City not found. Skipping...
# Processing Record 4 of Set 3 | junagarh
# City not found. Skipping...
# Processing Record 5 of Set 3 | bambous virieux
# City not found. Skipping...
# Processing Record 6 of Set 3 | natitingou
# City not found. Skipping...
# Processing Record 7 of Set 3 | kifri
# City not found. Skipping...
# Processing Record 8 of Set 3 | cabo san lucas
# City not found. Skipping...
# Processing Record 9 of Set 3 | san andres
# City not found. Skipping...
# Processing Record 10 of Set 3 | quang ngai
# City not found. Skipping...
# Processing Record 11 of Set 3 | vao
# City not found. Skipping...
# Processing Record 12 of Set 3 | tuatapere
# City not found. Skipping...
# Processing Record 13 of Set 3 | korla
# City not found. Skipping...
# Processing Record 14 of Set 3 | guerrero negro
# City not found. Skipping...
# Processing Record 15 of Set 3 | buin
# City not found. Skipping...
# Processing Record 16 of Set 3 | gornozavodsk
# City not found. Skipping...
# Processing Record 17 of Set 3 | shelburne
# City not found. Skipping...
# Processing Record 18 of Set 3 | luderitz
# City not found. Skipping...
# Processing Record 19 of Set 3 | weyburn
# City not found. Skipping...
# Processing Record 20 of Set 3 | faanui
# City not found. Skipping...
# Processing Record 21 of Set 3 | saskylakh
# City not found. Skipping...
# Processing Record 22 of Set 3 | pionerskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | kazanskaya
# City not found. Skipping...
# Processing Record 24 of Set 3 | honningsvag
# City not found. Skipping...
# Processing Record 25 of Set 3 | tiptur
# City not found. Skipping...
# Processing Record 26 of Set 3 | hamilton
# City not found. Skipping...
# Processing Record 27 of Set 3 | ada
# City not found. Skipping...
# Processing Record 28 of Set 3 | yumen
# City not found. Skipping...
# Processing Record 29 of Set 3 | el faiyum
# City not found. Skipping...
# Processing Record 30 of Set 3 | aktau
# City not found. Skipping...
# Processing Record 31 of Set 3 | provideniya
# City not found. Skipping...
# Processing Record 32 of Set 3 | pastavy
# City not found. Skipping...
# Processing Record 33 of Set 3 | namatanai
# City not found. Skipping...
# Processing Record 34 of Set 3 | ponta do sol
# City not found. Skipping...
# Processing Record 35 of Set 3 | gornopravdinsk
# City not found. Skipping...
# Processing Record 36 of Set 3 | victoria point
# City not found. Skipping...
# Processing Record 37 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 3 | belmonte
# City not found. Skipping...
# Processing Record 39 of Set 3 | ambilobe
# City not found. Skipping...
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | kudahuvadhoo
# City not found. Skipping...
# Processing Record 42 of Set 3 | noumea
# City not found. Skipping...
# Processing Record 43 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 44 of Set 3 | grand gaube
# City not found. Skipping...
# Processing Record 45 of Set 3 | parlakimidi
# City not found. Skipping...
# Processing Record 46 of Set 3 | alzamay
# City not found. Skipping...
# Processing Record 47 of Set 3 | farmington
# City not found. Skipping...
# Processing Record 48 of Set 3 | kapoeta
# City not found. Skipping...
# Processing Record 49 of Set 3 | dikson
# City not found. Skipping...
# Processing Record 1 of Set 4 | fayaoue
# City not found. Skipping...
# Processing Record 2 of Set 4 | east london
# City not found. Skipping...
# Processing Record 3 of Set 4 | khatanga
# City not found. Skipping...
# Processing Record 4 of Set 4 | clyde river
# City not found. Skipping...
# Processing Record 5 of Set 4 | zhigansk
# City not found. Skipping...
# Processing Record 6 of Set 4 | piacabucu
# City not found. Skipping...
# Processing Record 7 of Set 4 | tucuman
# City not found. Skipping...
# Processing Record 8 of Set 4 | broken hill
# City not found. Skipping...
# Processing Record 9 of Set 4 | carnarvon
# City not found. Skipping...
# Processing Record 10 of Set 4 | qandala
# City not found. Skipping...
# Processing Record 11 of Set 4 | makat
# City not found. Skipping...
# Processing Record 12 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 13 of Set 4 | kungurtug
# City not found. Skipping...
# Processing Record 14 of Set 4 | inhambane
# City not found. Skipping...
# Processing Record 15 of Set 4 | nemuro
# City not found. Skipping...
# Processing Record 16 of Set 4 | port lincoln
# City not found. Skipping...
# Processing Record 17 of Set 4 | taoudenni
# City not found. Skipping...
# Processing Record 18 of Set 4 | chernyshevskiy
# City not found. Skipping...
# Processing Record 19 of Set 4 | wuwei
# City not found. Skipping...
# Processing Record 20 of Set 4 | saint-francois
# City not found. Skipping...
# Processing Record 21 of Set 4 | sawtell
# City not found. Skipping...
# Processing Record 22 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 4 | rovaniemi
# City not found. Skipping...
# Processing Record 24 of Set 4 | qaqortoq
# City not found. Skipping...
# Processing Record 25 of Set 4 | komsomolskiy
# City not found. Skipping...
# Processing Record 26 of Set 4 | saint-philippe
# City not found. Skipping...
# Processing Record 27 of Set 4 | sawakin
# City not found. Skipping...
# Processing Record 28 of Set 4 | mosquera
# City not found. Skipping...
# Processing Record 29 of Set 4 | gornoye loo
# City not found. Skipping...
# Processing Record 30 of Set 4 | trairi
# City not found. Skipping...
# Processing Record 31 of Set 4 | mount isa
# City not found. Skipping...
# Processing Record 32 of Set 4 | westport
# City not found. Skipping...
# Processing Record 33 of Set 4 | el carmen
# City not found. Skipping...
# Processing Record 34 of Set 4 | caravelas
# City not found. Skipping...
# Processing Record 35 of Set 4 | chokurdakh
# City not found. Skipping...
# Processing Record 36 of Set 4 | salalah
# City not found. Skipping...
# Processing Record 37 of Set 4 | sumenep
# City not found. Skipping...
# Processing Record 38 of Set 4 | cidreira
# City not found. Skipping...
# Processing Record 39 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 4 | tongliao
# City not found. Skipping...
# Processing Record 41 of Set 4 | guarapari
# City not found. Skipping...
# Processing Record 42 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 4 | mahon
# City not found. Skipping...
# Processing Record 44 of Set 4 | valparaiso
# City not found. Skipping...
# Processing Record 45 of Set 4 | lompoc
# City not found. Skipping...
# Processing Record 46 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 4 | camacha
# City not found. Skipping...
# Processing Record 48 of Set 4 | baghdad
# City not found. Skipping...
# Processing Record 49 of Set 4 | thompson
# City not found. Skipping...
# Processing Record 1 of Set 5 | sturgis
# City not found. Skipping...
# Processing Record 2 of Set 5 | fukue
# City not found. Skipping...
# Processing Record 3 of Set 5 | rauma
# City not found. Skipping...
# Processing Record 4 of Set 5 | bethel
# City not found. Skipping...
# Processing Record 5 of Set 5 | padang
# City not found. Skipping...
# Processing Record 6 of Set 5 | cockburn town
# City not found. Skipping...
# Processing Record 7 of Set 5 | almaznyy
# City not found. Skipping...
# Processing Record 8 of Set 5 | port augusta
# City not found. Skipping...
# Processing Record 9 of Set 5 | baoning
# City not found. Skipping...
# Processing Record 10 of Set 5 | upernavik
# City not found. Skipping...
# Processing Record 11 of Set 5 | malanje
# City not found. Skipping...
# Processing Record 12 of Set 5 | srednekolymsk
# City not found. Skipping...
# Processing Record 13 of Set 5 | klaksvik
# City not found. Skipping...
# Processing Record 14 of Set 5 | sioux lookout
# City not found. Skipping...
# Processing Record 15 of Set 5 | stabat
# City not found. Skipping...
# Processing Record 16 of Set 5 | nome
# City not found. Skipping...
# Processing Record 17 of Set 5 | klyuchevskiy
# City not found. Skipping...
# Processing Record 18 of Set 5 | grande prairie
# City not found. Skipping...
# Processing Record 19 of Set 5 | lavrentiya
# City not found. Skipping...
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | omsukchan
# City not found. Skipping...
# Processing Record 22 of Set 5 | honiara
# City not found. Skipping...
# Processing Record 23 of Set 5 | palmerston
# City not found. Skipping...
# Processing Record 24 of Set 5 | katsuura
# City not found. Skipping...
# Processing Record 25 of Set 5 | sisimiut
# City not found. Skipping...
# Processing Record 26 of Set 5 | port moresby
# City not found. Skipping...
# Processing Record 27 of Set 5 | buala
# City not found. Skipping...
# Processing Record 28 of Set 5 | punta de piedra
# City not found. Skipping...
# Processing Record 29 of Set 5 | serenje
# City not found. Skipping...
# Processing Record 30 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 5 | takab
# City not found. Skipping...
# Processing Record 32 of Set 5 | amahai
# City not found. Skipping...
# Processing Record 33 of Set 5 | mozarlandia
# City not found. Skipping...
# Processing Record 34 of Set 5 | port hardy
# City not found. Skipping...
# Processing Record 35 of Set 5 | sabzevar
# City not found. Skipping...
# Processing Record 36 of Set 5 | carberry
# City not found. Skipping...
# Processing Record 37 of Set 5 | biak
# City not found. Skipping...
# Processing Record 38 of Set 5 | hostotipaquillo
# City not found. Skipping...
# Processing Record 39 of Set 5 | rawson
# City not found. Skipping...
# Processing Record 40 of Set 5 | pangnirtung
# City not found. Skipping...
# Processing Record 41 of Set 5 | kununurra
# City not found. Skipping...
# Processing Record 42 of Set 5 | vila franca do campo
# City not found. Skipping...
# Processing Record 43 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 5 | huarmey
# City not found. Skipping...
# Processing Record 45 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 5 | ayan
# City not found. Skipping...
# Processing Record 47 of Set 5 | praia
# City not found. Skipping...
# Processing Record 48 of Set 5 | nanortalik
# City not found. Skipping...
# Processing Record 49 of Set 5 | lamego
# City not found. Skipping...
# Processing Record 1 of Set 6 | elban
# City not found. Skipping...
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | nicoya
# City not found. Skipping...
# Processing Record 4 of Set 6 | jacksonville
# City not found. Skipping...
# Processing Record 5 of Set 6 | muisne
# City not found. Skipping...
# Processing Record 6 of Set 6 | uva
# City not found. Skipping...
# Processing Record 7 of Set 6 | parana
# City not found. Skipping...
# Processing Record 8 of Set 6 | boyolangu
# City not found. Skipping...
# Processing Record 9 of Set 6 | brokopondo
# City not found. Skipping...
# Processing Record 10 of Set 6 | tazovskiy
# City not found. Skipping...
# Processing Record 11 of Set 6 | norman wells
# City not found. Skipping...
# Processing Record 12 of Set 6 | bundaberg
# City not found. Skipping...
# Processing Record 13 of Set 6 | rio tercero
# City not found. Skipping...
# Processing Record 14 of Set 6 | yandoon
# City not found. Skipping...
# Processing Record 15 of Set 6 | pangody
# City not found. Skipping...
# Processing Record 16 of Set 6 | saint-prosper
# City not found. Skipping...
# Processing Record 17 of Set 6 | port macquarie
# City not found. Skipping...
# Processing Record 18 of Set 6 | adrar
# City not found. Skipping...
# Processing Record 19 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 6 | ust-kuyga
# City not found. Skipping...
# Processing Record 21 of Set 6 | gazli
# City not found. Skipping...
# Processing Record 22 of Set 6 | iqaluit
# City not found. Skipping...
# Processing Record 23 of Set 6 | dickson
# City not found. Skipping...
# Processing Record 24 of Set 6 | saint-pacome
# City not found. Skipping...
# Processing Record 25 of Set 6 | yulara
# City not found. Skipping...
# Processing Record 26 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 6 | kaitangata
# City not found. Skipping...
# Processing Record 28 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 29 of Set 6 | san cristobal
# City not found. Skipping...
# Processing Record 30 of Set 6 | half moon bay
# City not found. Skipping...
# Processing Record 31 of Set 6 | santarem
# City not found. Skipping...
# Processing Record 32 of Set 6 | mingshui
# City not found. Skipping...
# Processing Record 33 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 6 | shingu
# City not found. Skipping...
# Processing Record 35 of Set 6 | rohatyn
# City not found. Skipping...
# Processing Record 36 of Set 6 | turan
# City not found. Skipping...
# Processing Record 37 of Set 6 | cherskiy
# City not found. Skipping...
# Processing Record 38 of Set 6 | kluczbork
# City not found. Skipping...
# Processing Record 39 of Set 6 | guaira
# City not found. Skipping...
# Processing Record 40 of Set 6 | mount gambier
# City not found. Skipping...
# Processing Record 41 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 6 | estelle
# City not found. Skipping...
# Processing Record 43 of Set 6 | tias
# City not found. Skipping...
# Processing Record 44 of Set 6 | domoni
# City not found. Skipping...
# Processing Record 45 of Set 6 | qaanaaq
# City not found. Skipping...
# Processing Record 46 of Set 6 | vreed en hoop
# City not found. Skipping...
# Processing Record 47 of Set 6 | armidale
# City not found. Skipping...
# Processing Record 48 of Set 6 | severo-kurilsk
# City not found. Skipping...
# Processing Record 49 of Set 6 | marsabit
# City not found. Skipping...
# Processing Record 1 of Set 7 | atasu
# City not found. Skipping...
# Processing Record 2 of Set 7 | dedza
# City not found. Skipping...
# Processing Record 3 of Set 7 | gander
# City not found. Skipping...
# Processing Record 4 of Set 7 | dawson creek
# City not found. Skipping...
# Processing Record 5 of Set 7 | cangucu
# City not found. Skipping...
# Processing Record 6 of Set 7 | mahebourg
# City not found. Skipping...
# Processing Record 7 of Set 7 | losal
# City not found. Skipping...
# Processing Record 8 of Set 7 | port elizabeth
# City not found. Skipping...
# Processing Record 9 of Set 7 | castro
# City not found. Skipping...
# Processing Record 10 of Set 7 | xiaoweizhai
# City not found. Skipping...
# Processing Record 11 of Set 7 | the valley
# City not found. Skipping...
# Processing Record 12 of Set 7 | abonnema
# City not found. Skipping...
# Processing Record 13 of Set 7 | shitanjing
# City not found. Skipping...
# Processing Record 14 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 7 | dunedin
# City not found. Skipping...
# Processing Record 16 of Set 7 | vostok
# City not found. Skipping...
# Processing Record 17 of Set 7 | saint george
# City not found. Skipping...
# Processing Record 18 of Set 7 | sakakah
# City not found. Skipping...
# Processing Record 19 of Set 7 | lumsden
# City not found. Skipping...
# Processing Record 20 of Set 7 | hatillo
# City not found. Skipping...
# Processing Record 21 of Set 7 | hay river
# City not found. Skipping...
# Processing Record 22 of Set 7 | tonekabon
# City not found. Skipping...
# Processing Record 23 of Set 7 | nalut
# City not found. Skipping...
# Processing Record 24 of Set 7 | gobabis
# City not found. Skipping...
# Processing Record 25 of Set 7 | houma
# City not found. Skipping...
# Processing Record 26 of Set 7 | avera
# City not found. Skipping...
# Processing Record 27 of Set 7 | ucluelet
# City not found. Skipping...
# Processing Record 28 of Set 7 | raudeberg
# City not found. Skipping...
# Processing Record 29 of Set 7 | inirida
# City not found. Skipping...
# Processing Record 30 of Set 7 | egvekinot
# City not found. Skipping...
# Processing Record 31 of Set 7 | jiwani
# City not found. Skipping...
# Processing Record 32 of Set 7 | luba
# City not found. Skipping...
# Processing Record 33 of Set 7 | north platte
# City not found. Skipping...
# Processing Record 34 of Set 7 | kavaratti
# City not found. Skipping...
# Processing Record 35 of Set 7 | zhicheng
# City not found. Skipping...
# Processing Record 36 of Set 7 | salinas
# City not found. Skipping...
# Processing Record 37 of Set 7 | rameswaram
# City not found. Skipping...
# Processing Record 38 of Set 7 | iskateley
# City not found. Skipping...
# Processing Record 39 of Set 7 | svetlaya
# City not found. Skipping...
# Processing Record 40 of Set 7 | pochutla
# City not found. Skipping...
# Processing Record 41 of Set 7 | beloha
# City not found. Skipping...
# Processing Record 42 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 7 | sopelana
# City not found. Skipping...
# Processing Record 45 of Set 7 | terrace bay
# City not found. Skipping...
# Processing Record 46 of Set 7 | ahome
# City not found. Skipping...
# Processing Record 47 of Set 7 | una
# City not found. Skipping...
# Processing Record 48 of Set 7 | jumla
# City not found. Skipping...
# Processing Record 49 of Set 7 | umm kaddadah
# City not found. Skipping...
# Processing Record 1 of Set 8 | kandi
# City not found. Skipping...
# Processing Record 2 of Set 8 | souillac
# City not found. Skipping...
# Processing Record 3 of Set 8 | ocampo
# City not found. Skipping...
# Processing Record 4 of Set 8 | khonsa
# City not found. Skipping...
# Processing Record 5 of Set 8 | mae sot
# City not found. Skipping...
# Processing Record 6 of Set 8 | saint-augustin
# City not found. Skipping...
# Processing Record 7 of Set 8 | lorengau
# City not found. Skipping...
# Processing Record 8 of Set 8 | belyy yar
# City not found. Skipping...
# Processing Record 9 of Set 8 | bari
# City not found. Skipping...
# Processing Record 10 of Set 8 | el alto
# City not found. Skipping...
# Processing Record 11 of Set 8 | natal
# City not found. Skipping...
# Processing Record 12 of Set 8 | mananjary
# City not found. Skipping...
# Processing Record 13 of Set 8 | gambela
# City not found. Skipping...
# Processing Record 14 of Set 8 | touros
# City not found. Skipping...
# Processing Record 15 of Set 8 | marawi
# City not found. Skipping...
# Processing Record 16 of Set 8 | henties bay
# City not found. Skipping...
# Processing Record 17 of Set 8 | atar
# City not found. Skipping...
# Processing Record 18 of Set 8 | ilulissat
# City not found. Skipping...
# Processing Record 19 of Set 8 | mandalgovi
# City not found. Skipping...
# Processing Record 20 of Set 8 | cururupu
# City not found. Skipping...
# Processing Record 21 of Set 8 | arkhangelos
# City not found. Skipping...
# Processing Record 22 of Set 8 | richards bay
# City not found. Skipping...
# Processing Record 23 of Set 8 | abu samrah
# City not found. Skipping...
# Processing Record 24 of Set 8 | kismayo
# City not found. Skipping...
# Processing Record 25 of Set 8 | itarema
# City not found. Skipping...
# Processing Record 26 of Set 8 | batouri
# City not found. Skipping...
# Processing Record 27 of Set 8 | bilibino
# City not found. Skipping...
# Processing Record 28 of Set 8 | ca mau
# City not found. Skipping...
# Processing Record 29 of Set 8 | hasaki
# City not found. Skipping...
# Processing Record 30 of Set 8 | mufulira
# City not found. Skipping...
# Processing Record 31 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 8 | nishihara
# City not found. Skipping...
# Processing Record 33 of Set 8 | khash
# City not found. Skipping...
# Processing Record 34 of Set 8 | brae
# City not found. Skipping...
# Processing Record 35 of Set 8 | casimiro de abreu
# City not found. Skipping...
# Processing Record 36 of Set 8 | corner brook
# City not found. Skipping...
# Processing Record 37 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 8 | kurumkan
# City not found. Skipping...
# Processing Record 39 of Set 8 | alice springs
# City not found. Skipping...
# Processing Record 40 of Set 8 | kikwit
# City not found. Skipping...
# Processing Record 41 of Set 8 | ust-uda
# City not found. Skipping...
# Processing Record 42 of Set 8 | lazaro cardenas
# City not found. Skipping...
# Processing Record 43 of Set 8 | aden
# City not found. Skipping...
# Processing Record 44 of Set 8 | sibolga
# City not found. Skipping...
# Processing Record 45 of Set 8 | xingcheng
# City not found. Skipping...
# Processing Record 46 of Set 8 | vila velha
# City not found. Skipping...
# Processing Record 47 of Set 8 | grand-lahou
# City not found. Skipping...
# Processing Record 48 of Set 8 | ketchikan
# City not found. Skipping...
# Processing Record 49 of Set 8 | bandrele
# City not found. Skipping...
# Processing Record 1 of Set 9 | aras
# City not found. Skipping...
# Processing Record 2 of Set 9 | vila
# City not found. Skipping...
# Processing Record 3 of Set 9 | praia da vitoria
# City not found. Skipping...
# Processing Record 4 of Set 9 | turangi
# City not found. Skipping...
# Processing Record 5 of Set 9 | tual
# City not found. Skipping...
# Processing Record 6 of Set 9 | nelson bay
# City not found. Skipping...
# Processing Record 7 of Set 9 | miguelopolis
# City not found. Skipping...
# Processing Record 8 of Set 9 | hinton
# City not found. Skipping...
# Processing Record 9 of Set 9 | muros
# City not found. Skipping...
# Processing Record 10 of Set 9 | fort-shevchenko
# City not found. Skipping...
# Processing Record 11 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 12 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 9 | makakilo city
# City not found. Skipping...
# Processing Record 14 of Set 9 | raga
# City not found. Skipping...
# Processing Record 15 of Set 9 | chapais
# City not found. Skipping...
# Processing Record 16 of Set 9 | hvammstangi
# City not found. Skipping...
# Processing Record 17 of Set 9 | opuwo
# City not found. Skipping...
# Processing Record 18 of Set 9 | santa isabel do rio negro
# City not found. Skipping...
# Processing Record 19 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 9 | spearfish
# City not found. Skipping...
# Processing Record 21 of Set 9 | tezu
# City not found. Skipping...
# Processing Record 22 of Set 9 | seymchan
# City not found. Skipping...
# Processing Record 23 of Set 9 | port hedland
# City not found. Skipping...
# Processing Record 24 of Set 9 | yarovoye
# City not found. Skipping...
# Processing Record 25 of Set 9 | prince rupert
# City not found. Skipping...
# Processing Record 26 of Set 9 | north battleford
# City not found. Skipping...
# Processing Record 27 of Set 9 | dongsheng
# City not found. Skipping...
# Processing Record 28 of Set 9 | san pedro
# City not found. Skipping...
# Processing Record 29 of Set 9 | larsnes
# City not found. Skipping...
# Processing Record 30 of Set 9 | namibe
# City not found. Skipping...
# Processing Record 31 of Set 9 | hollola
# City not found. Skipping...
# Processing Record 32 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 9 | verdun
# City not found. Skipping...
# Processing Record 34 of Set 9 | boa vista
# City not found. Skipping...
# Processing Record 35 of Set 9 | rudbar
# City not found. Skipping...
# Processing Record 36 of Set 9 | piet retief
# City not found. Skipping...
# Processing Record 37 of Set 9 | svetlogorsk
# City not found. Skipping...
# Processing Record 38 of Set 9 | constitucion
# City not found. Skipping...
# Processing Record 39 of Set 9 | nipawin
# City not found. Skipping...
# Processing Record 40 of Set 9 | suruc
# City not found. Skipping...
# Processing Record 41 of Set 9 | camopi
# City not found. Skipping...
# Processing Record 42 of Set 9 | nhamunda
# City not found. Skipping...
# Processing Record 43 of Set 9 | nioro
# City not found. Skipping...
# Processing Record 44 of Set 9 | fortuna
# City not found. Skipping...
# Processing Record 45 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 9 | santa maria
# City not found. Skipping...
# Processing Record 47 of Set 9 | beringovskiy
# City not found. Skipping...
# Processing Record 48 of Set 9 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 49 of Set 9 | sal rei
# City not found. Skipping...
# Processing Record 1 of Set 10 | presidencia roque saenz pena
# City not found. Skipping...
# Processing Record 2 of Set 10 | rassvet
# City not found. Skipping...
# Processing Record 3 of Set 10 | la palma
# City not found. Skipping...
# Processing Record 4 of Set 10 | san carlos de bariloche
# City not found. Skipping...
# Processing Record 5 of Set 10 | tahta
# City not found. Skipping...
# Processing Record 6 of Set 10 | tornio
# City not found. Skipping...
# Processing Record 7 of Set 10 | novo aripuana
# City not found. Skipping...
# Processing Record 8 of Set 10 | scottsbluff
# City not found. Skipping...
# Processing Record 9 of Set 10 | biharamulo
# City not found. Skipping...
# Processing Record 10 of Set 10 | husavik
# City not found. Skipping...
# Processing Record 11 of Set 10 | shimanovsk
# City not found. Skipping...
# Processing Record 12 of Set 10 | sorland
# City not found. Skipping...
# Processing Record 13 of Set 10 | palmeira
# City not found. Skipping...
# Processing Record 14 of Set 10 | santa rosa
# City not found. Skipping...
# Processing Record 15 of Set 10 | pavlodar
# City not found. Skipping...
# Processing Record 16 of Set 10 | samfya
# City not found. Skipping...
# Processing Record 17 of Set 10 | sept-iles
# City not found. Skipping...
# Processing Record 18 of Set 10 | ayr
# City not found. Skipping...
# Processing Record 19 of Set 10 | yongchang
# City not found. Skipping...
# Processing Record 20 of Set 10 | saldanha
# City not found. Skipping...
# Processing Record 21 of Set 10 | jimo
# City not found. Skipping...
# Processing Record 22 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 10 | kiunga
# City not found. Skipping...
# Processing Record 24 of Set 10 | majene
# City not found. Skipping...
# Processing Record 25 of Set 10 | tatawin
# City not found. Skipping...
# Processing Record 26 of Set 10 | aldan
# City not found. Skipping...
# Processing Record 27 of Set 10 | oksfjord
# City not found. Skipping...
# Processing Record 28 of Set 10 | iranshahr
# City not found. Skipping...
# Processing Record 29 of Set 10 | saint-pierre
# City not found. Skipping...
# Processing Record 30 of Set 10 | williams lake
# City not found. Skipping...
# Processing Record 31 of Set 10 | hofn
# City not found. Skipping...
# Processing Record 32 of Set 10 | eureka
# City not found. Skipping...
# Processing Record 33 of Set 10 | hailin
# City not found. Skipping...
# Processing Record 34 of Set 10 | maputo
# City not found. Skipping...
# Processing Record 35 of Set 10 | pontianak
# City not found. Skipping...
# Processing Record 36 of Set 10 | puerto leguizamo
# City not found. Skipping...
# Processing Record 37 of Set 10 | matamoros
# City not found. Skipping...
# Processing Record 38 of Set 10 | lashio
# City not found. Skipping...
# Processing Record 39 of Set 10 | henzada
# City not found. Skipping...
# Processing Record 40 of Set 10 | college
# City not found. Skipping...
# Processing Record 41 of Set 10 | snasa
# City not found. Skipping...
# Processing Record 42 of Set 10 | byron bay
# City not found. Skipping...
# Processing Record 43 of Set 10 | alofi
# City not found. Skipping...
# Processing Record 44 of Set 10 | oistins
# City not found. Skipping...
# Processing Record 45 of Set 10 | merced
# City not found. Skipping...
# Processing Record 46 of Set 10 | bud
# City not found. Skipping...
# Processing Record 47 of Set 10 | jacareacanga
# City not found. Skipping...
# Processing Record 48 of Set 10 | pahrump
# City not found. Skipping...
# Processing Record 49 of Set 10 | aki
# City not found. Skipping...
# Processing Record 1 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 2 of Set 11 | galway
# City not found. Skipping...
# Processing Record 3 of Set 11 | springfield
# City not found. Skipping...
# Processing Record 4 of Set 11 | hambantota
# City not found. Skipping...
# Processing Record 5 of Set 11 | resplendor
# City not found. Skipping...
# Processing Record 6 of Set 11 | urucui
# City not found. Skipping...
# Processing Record 7 of Set 11 | manggar
# City not found. Skipping...
# Processing Record 8 of Set 11 | price
# City not found. Skipping...
# Processing Record 9 of Set 11 | totness
# City not found. Skipping...
# Processing Record 10 of Set 11 | kruisfontein
# City not found. Skipping...
# Processing Record 11 of Set 11 | monrovia
# City not found. Skipping...
# Processing Record 12 of Set 11 | lang son
# City not found. Skipping...
# Processing Record 13 of Set 11 | santa cruz
# City not found. Skipping...
# Processing Record 14 of Set 11 | payo
# City not found. Skipping...
# Processing Record 15 of Set 11 | umm lajj
# City not found. Skipping...
# Processing Record 16 of Set 11 | chimbote
# City not found. Skipping...
# Processing Record 17 of Set 11 | puerto baquerizo moreno
# City not found. Skipping...
# Processing Record 18 of Set 11 | ryde
# City not found. Skipping...
# Processing Record 19 of Set 11 | waipawa
# City not found. Skipping...
# Processing Record 20 of Set 11 | aleksandrovka
# City not found. Skipping...
# Processing Record 21 of Set 11 | sangar
# City not found. Skipping...
# Processing Record 22 of Set 11 | maldonado
# City not found. Skipping...
# Processing Record 23 of Set 11 | mitsamiouli
# City not found. Skipping...
# Processing Record 24 of Set 11 | bowen
# City not found. Skipping...
# Processing Record 25 of Set 11 | suao
# City not found. Skipping...
# Processing Record 26 of Set 11 | atambua
# City not found. Skipping...
# Processing Record 27 of Set 11 | paamiut
# City not found. Skipping...
# Processing Record 28 of Set 11 | lahuachaca
# City not found. Skipping...
# Processing Record 29 of Set 11 | litovko
# City not found. Skipping...
# Processing Record 30 of Set 11 | codrington
# City not found. Skipping...
# Processing Record 31 of Set 11 | baykit
# City not found. Skipping...
# Processing Record 32 of Set 11 | medicine hat
# City not found. Skipping...
# Processing Record 33 of Set 11 | rondonopolis
# City not found. Skipping...
# Processing Record 34 of Set 11 | cheremukhovo
# City not found. Skipping...
# Processing Record 35 of Set 11 | sestri levante
# City not found. Skipping...
# Processing Record 36 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 11 | kysyl-syr
# City not found. Skipping...
# Processing Record 38 of Set 11 | curup
# City not found. Skipping...
# Processing Record 39 of Set 11 | viedma
# City not found. Skipping...
# Processing Record 40 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 41 of Set 11 | omboue
# City not found. Skipping...
# Processing Record 42 of Set 11 | kargopol
# City not found. Skipping...
# Processing Record 43 of Set 11 | isangel
# City not found. Skipping...
# Processing Record 44 of Set 11 | pilar
# City not found. Skipping...
# Processing Record 45 of Set 11 | khandbari
# City not found. Skipping...
# Processing Record 46 of Set 11 | kloulklubed
# City not found. Skipping...
# Processing Record 47 of Set 11 | riyadh
# City not found. Skipping...
# Processing Record 48 of Set 11 | meulaboh
# City not found. Skipping...
# Processing Record 49 of Set 11 | antofagasta
# City not found. Skipping...
# Processing Record 1 of Set 12 | koumac
# City not found. Skipping...
# Processing Record 2 of Set 12 | laguna
# City not found. Skipping...
# Processing Record 3 of Set 12 | upington
# City not found. Skipping...
# Processing Record 4 of Set 12 | yaring
# City not found. Skipping...
# Processing Record 5 of Set 12 | zhangzhou
# City not found. Skipping...
# Processing Record 6 of Set 12 | vanavara
# City not found. Skipping...
# Processing Record 7 of Set 12 | erenhot
# City not found. Skipping...
# Processing Record 8 of Set 12 | dindori
# City not found. Skipping...
# Processing Record 9 of Set 12 | willowmore
# City not found. Skipping...
# Processing Record 10 of Set 12 | karratha
# City not found. Skipping...
# Processing Record 11 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 12 | aklavik
# City not found. Skipping...
# Processing Record 13 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 12 | maryborough
# City not found. Skipping...
# Processing Record 15 of Set 12 | anadyr
# City not found. Skipping...
# Processing Record 16 of Set 12 | hobyo
# City not found. Skipping...
# Processing Record 17 of Set 12 | kahului
# City not found. Skipping...
# Processing Record 18 of Set 12 | kiyasovo
# City not found. Skipping...
# Processing Record 19 of Set 12 | sao raimundo das mangabeiras
# City not found. Skipping...
# Processing Record 20 of Set 12 | rabo de peixe
# City not found. Skipping...
# Processing Record 21 of Set 12 | paredon
# City not found. Skipping...
# Processing Record 22 of Set 12 | pestovo
# City not found. Skipping...
# Processing Record 23 of Set 12 | udachnyy
# City not found. Skipping...
# Processing Record 24 of Set 12 | victoria
# City not found. Skipping...
# Processing Record 25 of Set 12 | athabasca
# City not found. Skipping...
# Processing Record 26 of Set 12 | maine-soroa
# City not found. Skipping...
# Processing Record 27 of Set 12 | rio grande
# City not found. Skipping...
# Processing Record 28 of Set 12 | furmanov
# City not found. Skipping...
# Processing Record 29 of Set 12 | paragominas
# City not found. Skipping...
# Processing Record 30 of Set 12 | balkhash
# City not found. Skipping...
# Processing Record 31 of Set 12 | srandakan
# City not found. Skipping...
# Processing Record 32 of Set 12 | sao joao da barra
# City not found. Skipping...
# Processing Record 33 of Set 12 | hasanabad
# City not found. Skipping...
# Processing Record 34 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 12 | sibu
# City not found. Skipping...
# Processing Record 36 of Set 12 | santiago de cao
# City not found. Skipping...
# Processing Record 37 of Set 12 | santa vitoria
# City not found. Skipping...
# Processing Record 38 of Set 12 | sambava
# City not found. Skipping...
# Processing Record 39 of Set 12 | ust-kalmanka
# City not found. Skipping...
# Processing Record 40 of Set 12 | berlevag
# City not found. Skipping...
# Processing Record 41 of Set 12 | dubenskiy
# City not found. Skipping...
# Processing Record 42 of Set 12 | burica
# City not found. Skipping...
# Processing Record 43 of Set 12 | araouane
# City not found. Skipping...
# Processing Record 44 of Set 12 | dalby
# City not found. Skipping...
# Processing Record 45 of Set 12 | fairbanks
# City not found. Skipping...
# Processing Record 46 of Set 12 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 47 of Set 12 | srivardhan
# City not found. Skipping...
# Processing Record 48 of Set 12 | sao filipe
# City not found. Skipping...
# Processing Record 49 of Set 12 | sajalices
# City not found. Skipping...
# Processing Record 1 of Set 13 | berdyuzhye
# City not found. Skipping...
# Processing Record 2 of Set 13 | hecun
# City not found. Skipping...
# Processing Record 3 of Set 13 | bahir dar
# City not found. Skipping...
# Processing Record 4 of Set 13 | puerto escondido
# City not found. Skipping...
# Processing Record 5 of Set 13 | highland village
# City not found. Skipping...
# Processing Record 6 of Set 13 | asau
# City not found. Skipping...
# Processing Record 7 of Set 13 | bongor
# City not found. Skipping...
# Processing Record 8 of Set 13 | ostrovnoy
# City not found. Skipping...
# Processing Record 9 of Set 13 | saint-georges
# City not found. Skipping...
# Processing Record 10 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 11 of Set 13 | celestun
# City not found. Skipping...
# Processing Record 12 of Set 13 | sitka
# City not found. Skipping...
# Processing Record 13 of Set 13 | salym
# City not found. Skipping...
# Processing Record 14 of Set 13 | tomatlan
# City not found. Skipping...
# Processing Record 15 of Set 13 | kavieng
# City not found. Skipping...
# Processing Record 16 of Set 13 | san patricio
# City not found. Skipping...
# Processing Record 17 of Set 13 | gorom-gorom
# City not found. Skipping...
# Processing Record 18 of Set 13 | imbituba
# City not found. Skipping...
# Processing Record 19 of Set 13 | luwuk
# City not found. Skipping...
# Processing Record 20 of Set 13 | longyearbyen
# City not found. Skipping...
# Processing Record 21 of Set 13 | clocolan
# City not found. Skipping...
# Processing Record 22 of Set 13 | mount pleasant
# City not found. Skipping...
# Processing Record 23 of Set 13 | oum hadjer
# City not found. Skipping...
# Processing Record 24 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 13 | benghazi
# City not found. Skipping...
# ===========================================================
# Data Retrieval Complete
# ===========================================================

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Convert Raw Data to DataFrame
#=======================================================================================
updated_weather_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country_id,
    "Date": date,
})

#Getting rid of any cities that could not be found(skipped) using the dropna function
updated_weather_df = weather_df.dropna(how="any")

# %%
#Export the city data into a .csv.
#================================================
updated_weather_df.to_csv("C:/Users/DeferentAtom94/OneDrive/Desktop/Resources/Pandas_Challenge/weather_data.csv", index=False)
#Display the DataFrame

updated_weather_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a scatter plot for latitude vs max temperature.
x_values = updated_weather_df['Lat']
y_values = updated_weather_df['Max Temp']
fig1, ax1 = plt.subplots(figsize=(14,10))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude', fontsize=16)
plt.ylabel('Max Temperature (F)', fontsize=16)
plt.title(f"City Latitude vs Max Temperature",fontsize=22)
plt.grid()

#Save figure as png and show
plt.savefig("../Downloads/latitude_vs_temperature.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a scatter plot for latitude vs humidity.
x_values = updated_weather_df['Lat']
y_values = updated_weather_df['Humidity']
fig1, ax1 = plt.subplots(figsize=(14, 10))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude',fontsize=16)
plt.ylabel('Humidity (%)',fontsize=16)
plt.title(f'Latitude vs Humidity',fontsize=22)
plt.grid()
#Save figure as png and show
plt.savefig("../Downloads/latitude_vs_humidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot for latitude vs cloudiness.
x_values = updated_weather_df['Lat']
y_values = updated_weather_df['Cloudiness']
fig1, ax1 = plt.subplots(figsize=(14,10))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude', fontsize=16)
plt.ylabel('Cloudiness (%)', fontsize=16)
plt.title(f'Latitude vs Cloudiness',fontsize=22 )
plt.grid()
#Save figure as png and show
plt.savefig("../Downloads/latitude_vs_cloudiness.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot for latitude vs wind speed.
x_values = updated_weather_df['Lat']
y_values = updated_weather_df['Wind Speed']
fig1, ax1 = plt.subplots(figsize=(14,10))
plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
plt.xlabel('Latitude',fontsize=16 )
plt.ylabel('Wind Speed (mph)', fontsize=16)
plt.title(f'Latitude vs Wind Speed', fontsize=22)
plt.grid()
#Save figure as png and show
plt.savefig("../Downloads/latitude_vs_wind_speed.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Linear Regression
#===================================================================================================
#Create a function to perform the linear regression plot, print the r-squared and correlation

def  regression_plot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    #Get regression values (x values times slope plus intercept)
    regress_values = x_values * slope + intercept
    
    #Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    fig1, ax1 = plt.subplots(figsize=(10,8))
    plt.scatter(x_values, y_values,alpha = 0.80, edgecolors = "k", linewidths = 1)
    plt.xlabel(x_label,fontsize = 16)
    plt.ylabel(y_label,fontsize = 16)
    
    #Create an if for the ylim
    if ylim is not None:
        plt.ylim(0, ylim)
    
    #Title string and font size
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} ",fontsize = 16)
    
    #The annotate() function in pyplot module of matplotlib library is used to annotate the point xy with texts(GeeksforGeeks)
    #
    plt.annotate(line_eq,xy=(10, 50),fontsize=22,xycoords='data',xytext=(0.4, 0.4),\
                 textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    
    plt.annotate(line_eq,xy=(-50, 40),fontsize=22,xycoords='data',xytext=(0.4, 0.3),\
                 textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    
    plt.annotate(line_eq,xy=(10, 25),fontsize=22,xycoords='data',xytext=(0.4, 0.4),\
                 textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    
    #Print r square value
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")
    return plt.plot(x_values,regress_values,"r-")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create Northern and Southern Hemisphere DataFrames
#=======================================================================================
#Creating my Northern Hemisphere data frame from updated weather df Latitude is greater than equal to 0
northern_hemisphere_weather_df = updated_weather_df.loc[updated_weather_df["Lat"] >= 0]

#Creating my Southern Hemisphere data frame from updated weather df Latitude is less than equal to 0
southern_hemisphere_weather_df = updated_weather_df.loc[updated_weather_df["Lat"] < 0]

# %%
#Create a scatter plot for latitude vs max temp (northern hemisphere)
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Max Temp']
regression_plot(x_values, y_values, "Lat", "Max Temp (F)", "Northern",(0, 0))

#Save figure as png and show
plt.savefig("../Downloads/Northern_Hemisphere_MaxTemp_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.6644951847801372
# The correlation between both factors is -0.82

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs cloudiness (southern hemisphere)
#=======================================================================================
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
regression_plot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))

#Save figure as png and show
plt.savefig("../Downloads/Southern_Hemisphere_MaxTemp_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.050144508564721905
# The correlation between both factors is 0.22

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs humditiy (northern hemisphere)
#=================================================================================
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Humidity']
regression_plot(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(40, 20))

#Save figure as png and show
plt.savefig("../Downloads/Northern_Hemisphere_Humidity_vs_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.010729512501511105
# The correlation between both factors is 0.1

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs humditiy (southern hemisphere)
#===================================================================================================
x_values1 = southern_hemisphere_weather_df['Lat']
y_values1 = southern_hemisphere_weather_df['Humidity']
regression_plot(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(40, 20), 150)

#Save figure as png and show
plt.savefig("../Downloads/Southern_Hemisphere_Humidity_vs_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.050144508564721905
# The correlation between both factors is 0.22

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs cloudiness (northern hemisphere)
#========================================================================================
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Cloudiness']
regression_plot(x_values, y_values, "Latitude", "Cloudiness(%)", "Northern",(30, 50))

#Save figure as png and show
plt.savefig("../Downloads/Northern Hemisphere_Cloudiness_vs_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.007627485925231671
# The correlation between both factors is -0.09

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs cloudiness (southern hemisphere)
#================================================================================
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Cloudiness']
regression_plot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
 
#Save figure as png and show
plt.savefig("../Downloads/Southern_Hemisphere_Cloudiness_vs_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.050144508564721905
# The correlation between both factors is 0.22

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs wind speed(northern hemisphere)
#==================================================================================================
x_values = northern_hemisphere_weather_df['Lat']
y_values = northern_hemisphere_weather_df['Wind Speed']
regression_plot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))

#Save figure as png and show
plt.savefig("../Downloads/Northern_Hemisphere_Wind_Speed_vs_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.011478610492563554
# The correlation between both factors is 0.11

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create a scatter plot for latitude vs wind speed (southern hemisphere)
#===========================================================================================
x_values = southern_hemisphere_weather_df['Lat']
y_values = southern_hemisphere_weather_df['Wind Speed']
regression_plot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25), ylim=40)

#Save figure as png and show
plt.savefig("../Downloads/Southern_Hemisphere_Wind_Speed_vs_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.1040436814752203
# The correlation between both factors is -0.32
